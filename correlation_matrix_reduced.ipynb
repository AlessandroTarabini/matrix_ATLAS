# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import mplhep as hep
from matplotlib.patches import Rectangle
from pathlib import Path
from typing import List, Union
from scipy.linalg import solve_triangular, qr
import json
import re
import os
import uproot
import importlib.util
plt.style.use(hep.style.CMS)

# %%
label_map = {
    "pth_bin0": "r_PTH_0p0_5p0",
    "pth_bin1": "r_PTH_5p0_10p0",
    "pth_bin2": "r_PTH_10p0_15p0",
    "pth_bin3": "r_PTH_15p0_20p0",
    "pth_bin4": "r_PTH_20p0_25p0",
    "pth_bin5": "r_PTH_25p0_30p0",
    "pth_bin6": "r_PTH_30p0_35p0",
    "pth_bin7": "r_PTH_35p0_45p0",
    "pth_bin8": "r_PTH_45p0_60p0",
    "pth_bin9": "r_PTH_60p0_80p0",
    "pth_bin10": "r_PTH_80p0_100p0",
    "pth_bin11": "r_PTH_100p0_120p0",
    "pth_bin12": "r_PTH_120p0_140p0",
    "pth_bin13": "r_PTH_140p0_170p0",
    "pth_bin14": "r_PTH_170p0_200p0",
    "pth_bin15": "r_PTH_200p0_250p0",
    "pth_bin16": "r_PTH_250p0_350p0",
    "pth_bin17": "r_PTH_350p0_450p0",
    "pth_bin18": "r_PTH_450p0_10000p0",
    "nj_bin0": "r_NJ_0p0_1p0",
    "nj_bin1": "r_NJ_1p0_2p0",
    "nj_bin2": "r_NJ_2p0_3p0",
    "nj_bin3": "r_NJ_3p0_4p0",
    "nj_bin4": "r_NJ_4p0_100p0",
    "ptj0_bin0": "r_PTJ0_m10000p0_30p0",
    "ptj0_bin1": "r_PTJ0_30p0_40p0",
    "ptj0_bin2": "r_PTJ0_40p0_55p0",
    "ptj0_bin3": "r_PTJ0_55p0_75p0",
    "ptj0_bin4": "r_PTJ0_75p0_95p0",
    "ptj0_bin5": "r_PTJ0_95p0_120p0",
    "ptj0_bin6": "r_PTJ0_120p0_150p0",
    "ptj0_bin7": "r_PTJ0_150p0_200p0",
    "ptj0_bin8": "r_PTJ0_200p0_10000p0",
    # "rapidity_bin0": "r_YH_0p0_0p15",
    # "rapidity_bin1": "r_YH_0p15_0p3",
    # "rapidity_bin2": "r_YH_0p3_0p45",
    # "rapidity_bin3": "r_YH_0p45_0p6",
    # "rapidity_bin4": "r_YH_0p6_0p75",
    # "rapidity_bin5": "r_YH_0p75_0p9",
    # "rapidity_bin6": "r_YH_0p9_1p2",
    # "rapidity_bin7": "r_YH_1p2_1p6",
    # "rapidity_bin8": "r_YH_1p6_2p0",
    # "rapidity_bin9": "r_YH_2p0_2p5",
}


label_map_theory = {
    "PTH_bin0": "r_PTH_0p0_5p0",
    "PTH_bin1": "r_PTH_5p0_10p0",
    "PTH_bin2": "r_PTH_10p0_15p0",
    "PTH_bin3": "r_PTH_15p0_20p0",
    "PTH_bin4": "r_PTH_20p0_25p0",
    "PTH_bin5": "r_PTH_25p0_30p0",
    "PTH_bin6": "r_PTH_30p0_35p0",
    "PTH_bin7": "r_PTH_35p0_45p0",
    "PTH_bin8": "r_PTH_45p0_60p0",
    "PTH_bin9": "r_PTH_60p0_80p0",
    "PTH_bin10": "r_PTH_80p0_100p0",
    "PTH_bin11": "r_PTH_100p0_120p0",
    "PTH_bin12": "r_PTH_120p0_140p0",
    "PTH_bin13": "r_PTH_140p0_170p0",
    "PTH_bin14": "r_PTH_170p0_200p0",
    "PTH_bin15": "r_PTH_200p0_250p0",
    "PTH_bin16": "r_PTH_250p0_350p0",
    "PTH_bin17": "r_PTH_350p0_450p0",
    "PTH_bin18": "r_PTH_450p0_10000p0",
    "NJ_bin0": "r_NJ_0p0_1p0",
    "NJ_bin1": "r_NJ_1p0_2p0",
    "NJ_bin2": "r_NJ_2p0_3p0",
    "NJ_bin3": "r_NJ_3p0_4p0",
    "NJ_bin4": "r_NJ_4p0_100p0",
    "PTJ0_bin0": "r_PTJ0_m10000p0_30p0",
    "PTJ0_bin1": "r_PTJ0_30p0_40p0",
    "PTJ0_bin2": "r_PTJ0_40p0_55p0",
    "PTJ0_bin3": "r_PTJ0_55p0_75p0",
    "PTJ0_bin4": "r_PTJ0_75p0_95p0",
    "PTJ0_bin5": "r_PTJ0_95p0_120p0",
    "PTJ0_bin6": "r_PTJ0_120p0_150p0",
    "PTJ0_bin7": "r_PTJ0_150p0_200p0",
    "PTJ0_bin8": "r_PTJ0_200p0_10000p0",
    # "YH_bin0": "r_YH_0p0_0p15",
    # "YH_bin1": "r_YH_0p15_0p3",
    # "YH_bin2": "r_YH_0p3_0p45",
    # "YH_bin3": "r_YH_0p45_0p6",
    # "YH_bin4": "r_YH_0p6_0p75",
    # "YH_bin5": "r_YH_0p75_0p9",
    # "YH_bin6": "r_YH_0p9_1p2",
    # "YH_bin7": "r_YH_1p2_1p6",
    # "YH_bin8": "r_YH_1p6_2p0",
    # "YH_bin9": "r_YH_2p0_2p5",
}

# %%
def read_bootstrap_file(path: Union[str, Path], prefix: str) -> pd.DataFrame:
    """
    Read one bootstrap text file.
    - Drops the first 4 header lines.
    - Drops first data column (replica index).
    - Returns only bin columns, prefixed to keep names unique across files.
    """
    path = Path(path)

    # Header in these files starts with '#'; this also skips the first 4 lines
    df = pd.read_csv(path, sep=r"\s+", comment="#", header=None)

    # Drop first row (text labels) and first column (replica/bin label)
    df = df.iloc[:, 1:].copy()
    df.columns = [f"{prefix}_bin{i}" for i in range(df.shape[1])]

    return df


def build_df(
    pth_path: Union[str, Path],
    nj_path: Union[str, Path],
    # rapidity_path: Union[str, Path],
    ptj0_path: Union[str, Path],
) -> pd.DataFrame:
    """Read all three files and return one dataframe per variable"""
    pth = read_bootstrap_file(pth_path, "pth")
    nj = read_bootstrap_file(nj_path, "nj")
    # rapidity = read_bootstrap_file(rapidity_path, "rapidity")
    ptj0 = read_bootstrap_file(ptj0_path, "ptj0")

    # Check if all variables have the same number of replicas
    # if not (len(pth) == len(nj) == len(ptj0) == len(rapidity)):
    # if not (len(pth) == len(nj)):
    if not (len(pth) == len(nj) == len(ptj0)):
        raise ValueError("Replica counts do not match across files.")

    # return pd.concat([pth, nj, rapidity, ptj0], axis=1)
    return pd.concat([pth, nj, ptj0], axis=1)
    # return pd.concat([pth, nj], axis=1)
    # return pd.concat([pth], axis=1)

## Helper function to invert a matrix and compute correlations from covariances
def invert_matrix(matrix: pd.DataFrame) -> pd.DataFrame:
    return pd.DataFrame(
        np.linalg.inv(matrix.to_numpy()),
        index=matrix.index,
        columns=matrix.columns,
    )

## Helper function to compute correlations from covariances
def compute_corr(cov: pd.DataFrame) -> pd.DataFrame:
    sigma = np.sqrt(np.diag(cov.to_numpy()))
    denom = np.outer(sigma, sigma)
    corr = np.divide(
        cov.to_numpy(),
        denom,
        out=np.zeros_like(cov.to_numpy()), 
        where=denom != 0,
    )
    return pd.DataFrame(corr, index=cov.index, columns=cov.columns)

# Plot correlation matrix at gen-level
def plot_corr(_corr_gen, title="Correlation Matrix (Generator Level)", save_path=None, label_map=None):
    corr_gen_mask = np.triu(np.ones_like(_corr_gen, dtype=bool), k=1)
    fig_corr_gen, ax_corr_gen = plt.subplots(figsize=(28, 18), constrained_layout=True)
    sns.heatmap(
        _corr_gen,
        ax=ax_corr_gen,
        cmap=palette,
        mask=corr_gen_mask,
        vmin=-1,
        vmax=1,
        annot=True,
        fmt=".2f",
        center=0,
        square=True,
        annot_kws={"size": 10, "weight": "bold"},
        cbar_kws={"label": "Correlation"},
    )
    ax_corr_gen.set_title(title)
    ax_corr_gen.set_xlabel("Bins")
    ax_corr_gen.set_ylabel("Bins")
    
    # ---- LABEL TRANSLATION LOGIC ----
    if label_map is not None:
        # assume index == columns order
        original_labels = list(_corr_gen.index)

        translated_labels = [
            label_map.get(lbl, lbl) for lbl in original_labels
        ]

        ax_corr_gen.set_xticklabels(translated_labels, rotation=90, fontsize=12)
        ax_corr_gen.set_yticklabels(translated_labels, rotation=0, fontsize=12)
        # IMPORTANT: re-apply tick styling AFTER setting labels
        ax_corr_gen.tick_params(
            axis="x",
            which="both",
            length=0,   # <- removes tick marks
            bottom=False,
            top=False
        )
        ax_corr_gen.tick_params(
            axis="y",
            which="both",
            length=0,   # <- removes tick marks
            left=False,
            right=False
        )

    else:
        ax_corr_gen.tick_params(
            axis="x", which="both", labelrotation=90, bottom=False, top=False, length=0, labelsize=12
        )
        ax_corr_gen.tick_params(
            axis="y", which="both", labelrotation=0, left=False, right=False, length=0, labelsize=12
        )

    ax_corr_gen.minorticks_off()
    n_bins = corr_gen.shape[0]
    for b in (b1, b2, b3):
        # Draw only on the visible lower triangle
        ax_corr_gen.plot([0, b], [b, b], color="black", lw=1)
        ax_corr_gen.plot([b, b], [b, n_bins], color="black", lw=1)
    ax_corr_gen.add_patch(Rectangle((0, 0), n_bins, n_bins, fill=False, edgecolor="black", lw=2))
    if save_path:
        plt.savefig(save_path, dpi=300)
    else:
        plt.show()

# Plot covariance matrix at gen-level
def plot_cov(_corr_gen, title="Covariance Matrix (Generator Level)", save_path=None, label_map=None):
    corr_gen_mask = np.triu(np.ones_like(_corr_gen, dtype=bool), k=1)
    fig_corr_gen, ax_corr_gen = plt.subplots(figsize=(28, 18), constrained_layout=True)
    sns.heatmap(
        _corr_gen,
        ax=ax_corr_gen,
        cmap=palette,
        mask=corr_gen_mask,
        vmin = _corr_gen.to_numpy().min(),
        vmax = _corr_gen.to_numpy().max(),
        annot=True,
        fmt=".2f",
        center=0,
        square=True,
        annot_kws={"size": 10, "weight": "bold"},
        cbar_kws={"label": r"Covariance [fb$^{2}$]"},
        # cbar_kws={"label": "Theoretical Covariance"},
    )
    ax_corr_gen.set_title(title)
    ax_corr_gen.set_xlabel("Bins")
    ax_corr_gen.set_ylabel("Bins")
    
    # ---- LABEL TRANSLATION LOGIC ----
    if label_map is not None:
        # assume index == columns order
        original_labels = list(_corr_gen.index)

        translated_labels = [
            label_map.get(lbl, lbl) for lbl in original_labels
        ]

        ax_corr_gen.set_xticklabels(translated_labels, rotation=90, fontsize=12)
        ax_corr_gen.set_yticklabels(translated_labels, rotation=0, fontsize=12)
        # IMPORTANT: re-apply tick styling AFTER setting labels
        ax_corr_gen.tick_params(
            axis="x",
            which="both",
            length=0,   # <- removes tick marks
            bottom=False,
            top=False
        )
        ax_corr_gen.tick_params(
            axis="y",
            which="both",
            length=0,   # <- removes tick marks
            left=False,
            right=False
        )

    else:
        ax_corr_gen.tick_params(
            axis="x", which="both", labelrotation=90, bottom=False, top=False, length=0, labelsize=12
        )
        ax_corr_gen.tick_params(
            axis="y", which="both", labelrotation=0, left=False, right=False, length=0, labelsize=12
        )

    ax_corr_gen.minorticks_off()

    if save_path:
        plt.savefig(save_path, dpi=300)
    else:
        plt.show()

# %%
# VARIABLE_PREFIXES = ("pth_", "nj_", "rapidity_", "ptj0_")
VARIABLE_PREFIXES = ("pth_", "nj_", "ptj0_")
# VARIABLE_PREFIXES = ("PTH_", "NJ_", "PTJ0_")
# VARIABLE_PREFIXES = ("pth_", "nj_")

CAT = ["cat0", "cat1", "cat2"]

YEARS = ["2022", "2023", "2024"]
# YEARS = ["2022"]


def zero_intra_variable_off_diagonal_block(matrix: pd.DataFrame) -> pd.DataFrame:
    out = matrix.copy()
    cols = list(out.columns)
    for pref in VARIABLE_PREFIXES:
        group = [c for c in cols if c.startswith(pref)]
        for ci in group:
            for cj in group:
                if ci != cj:
                    out.loc[ci, cj] = 0.0
    return out

def zero_below_threshold_keep_diag(matrix: pd.DataFrame, threshold: float, use_abs: bool = True) -> pd.DataFrame:
    out = matrix.copy()
    vals = out.abs() if use_abs else out
    mask = vals < threshold
    np.fill_diagonal(mask.values, False)
    out[mask] = 0.0
    return out

def corr_from_cov(cov_mat: pd.DataFrame) -> pd.DataFrame:
    v = np.diag(cov_mat.to_numpy())
    sigma = np.sqrt(np.clip(v, 0.0, None))
    with np.errstate(divide="ignore", invalid="ignore"):
        outer = np.outer(1.0 / sigma, 1.0 / sigma)
        arr = outer * cov_mat.to_numpy()
    arr = np.nan_to_num(arr, nan=0.0, posinf=0.0, neginf=0.0)
    np.fill_diagonal(arr, 1.0)
    return pd.DataFrame(arr, index=cov_mat.index, columns=cov_mat.columns)

####################################################################################################

cov = {}
corr = {}
df_dict = {}

for cat in CAT:
    
    # We can combine the sidebands across the YEARS (also done in FinalFits)
    df_combined = pd.DataFrame()
    
    for year in YEARS:
        df = build_df(
            f"bootstrap/bootstrap_sideband_counts_pth_{cat}_{year}.txt",
            f"bootstrap/bootstrap_sideband_counts_nj_{cat}_{year}.txt",
            # f"bootstrap/bootstrap_sideband_counts_rapidity_{cat}_{year}.txt",
            f"bootstrap/bootstrap_sideband_counts_ptj0_{cat}_{year}.txt",
        )
                
        df_combined = df_combined.add(df, fill_value=0)
    
    df_combined = df_combined.reindex(columns=df.columns)    
    
    c = df_combined.cov()
    ## To force setting all off-diagonal entries within each observable to zero uncomment below
    ## This can be useful when running on few replicas where fluctuations can induce non-zero off-diagonal entries
    c = zero_intra_variable_off_diagonal_block(c)
    ## This can be used to set all elements below a threshold to zero
    # c = zero_below_threshold_keep_diag(c, 200)
    ## Force the symmetry of the covariance matrix
    c = 0.5 * (c + c.T)
    
    # label_to_drop = c.index[12]
    # c = c.drop(index=label_to_drop, columns=label_to_drop)
    cov[cat] = c
    corr[cat] = df_combined.corr()#.drop(index=label_to_drop, columns=label_to_drop)

# %%
hep.style.use("CMS")
palette = sns.diverging_palette(240, 10, n=20, as_cmap=True)


# Boundaries between variable blocks (pth | nj | ptj0); same layout for all categories
_ref = cov[CAT[-1]]  # same bin layout for all categories

b1 = len([c for c in _ref.columns if c.startswith("pth_")])
b2 = b1 + len([c for c in _ref.columns if c.startswith("nj_")])
b3 = b2 + len([c for c in _ref.columns if c.startswith("ptj0_")]) + 1


def _decorate_matrix_ax(ax, n_bins: int) -> None:
    ax.tick_params(axis="x", which="both", labelrotation=90, bottom=False, top=False, length=0)
    ax.tick_params(axis="y", which="both", labelrotation=0, left=False, right=False, length=0)
    ax.minorticks_off()
    for b in (b1, b2, b3):
        ax.plot([0, b], [b, b], color="black", lw=1)
        ax.plot([b, b], [b, n_bins], color="black", lw=1)
    ax.add_patch(Rectangle((0, 0), n_bins, n_bins, fill=False, edgecolor="black", lw=2))


# 1) Covariance matrices (one panel per category)
cov_scale = 1e3
nc = len(CAT)
fig_cov, axes_cov = plt.subplots(1, nc, figsize=(10 * nc, 9), constrained_layout=True)
if nc == 1:
    axes_cov = np.array([axes_cov])

for ax, cat in zip(axes_cov.flat, CAT):
    cov_plot = cov[cat] / cov_scale
    cov_mask = np.triu(np.ones_like(cov_plot, dtype=bool), k=1)
    sns.heatmap(
        cov_plot,
        ax=ax,
        cmap=palette,
        mask=cov_mask,
        annot=True,
        fmt=".1f",
        # square=True,
        annot_kws={"size": 8, "weight": "bold"},
        cbar_kws={"label": r"Cov [$\times 10^3$]", 'pad': .005},
    )
    ax.set_title(f"Covariance — {cat}")
    ax.set_xlabel("Bins")
    ax.set_ylabel("Bins")
    _decorate_matrix_ax(ax, cov_plot.shape[0])

plt.savefig(f"cov_matrix_perCategory_reduced.pdf", bbox_inches="tight")
plt.show()

# 2) Correlation matrices (one panel per category)
fig_corr, axes_corr = plt.subplots(1, nc, figsize=(10 * nc, 9), constrained_layout=True)
if nc == 1:
    axes_corr = np.array([axes_corr])

for ax, cat in zip(axes_corr.flat, CAT):
    # cmat = corr[cat]
    cmat = corr_from_cov(cov[cat])
    corr_mask = np.triu(np.ones_like(cmat, dtype=bool), k=1)
    sns.heatmap(
        cmat,
        ax=ax,
        cmap=palette,
        mask=corr_mask,
        vmin=-1,
        vmax=1,
        annot=True,
        fmt=".2f",
        center=0,
        square=True,
        annot_kws={"size": 8, "weight": "bold"},
        cbar_kws={"label": "Correlation", 'pad': .005},
    )
    ax.set_title(f"Correlation — {cat}")
    ax.set_xlabel("Bins")
    ax.set_ylabel("Bins")
    _decorate_matrix_ax(ax, cmat.shape[0])

plt.savefig(f"cor_matrix_perCategory_reduced.pdf", bbox_inches="tight")
plt.show()

# %%
fig_corr, ax = plt.subplots(
    figsize=(24, 18),
    constrained_layout=True
)

cat = "cat0"

cmat = corr_from_cov(cov[cat])
corr_mask = np.triu(np.ones_like(cmat, dtype=bool), k=1)

sns.heatmap(
    cmat,
    ax=ax,
    cmap=palette,
    mask=corr_mask,
    vmin=-1,
    vmax=1,
    annot=True,
    fmt=".2f",
    center=0,
    square=True,
    annot_kws={"size": 8, "weight": "bold"},
    cbar_kws={"label": "Correlation", "pad": 0.005},
)

ax.set_title(f"Correlation — {cat}")
ax.set_xlabel("Bins")
ax.set_ylabel("Bins")

_decorate_matrix_ax(ax, cmat.shape[0])

plt.show()

# %%
## Loading the response matrix
def read_response_block(path: str):
    """Read response_matrix_*.txt and return numeric square block."""
    raw = pd.read_csv(path, sep=r"\s+", header=None)
    block = raw.iloc[1:, 1:].astype(float).to_numpy()
    # if block.shape[0] != block.shape[1]:
    #     raise ValueError(f"Response block is not square for {path}: {block.shape}")
    return block


def response_paths_for_category(cat: str) -> dict:
    """Lumi-weighted response .txt paths per observable for one reco category."""
    suffix = "combined"
    return {
        "ptj0": f"response_matrix_{suffix}/response_matrix_PTJ0_{cat}.txt",
        "nj": f"response_matrix_{suffix}/response_matrix_NJ_{cat}.txt",
        # "rapidity": f"response_matrix_{suffix}/response_matrix_YH_{cat}.txt",
        "pth": f"response_matrix_{suffix}/response_matrix_PTH_{cat}.txt",
    }


def build_block_diagonal_resp(cov_mat: pd.DataFrame, cat: str) -> pd.DataFrame:
    resp_files = response_paths_for_category(cat)
    cols = list(cov_mat.columns)
    prefix_order = []
    for col in cols:
        pref = col.split("_", 1)[0]
        if pref not in prefix_order:
            prefix_order.append(pref)
    
    resp = pd.DataFrame(0.0, index=cov_mat.index, columns=cov_mat.columns)
    start = 0
    for pref in prefix_order:
        block_cols = [c for c in cols if c.startswith(f"{pref}_")]
        n = len(block_cols)
        if pref not in resp_files:
            raise ValueError(f"No response matrix file configured for prefix '{pref}'")

        block = read_response_block(resp_files[pref])
        # if pref == "ptj0":
        #     block = block[1:, 1:] # Drop first row and first column to remove the underflow bin for pTj0
        if block.shape != (n, n):
            raise ValueError(
                f"Shape mismatch for {resp_files[pref]}: got {block.shape}, expected {(n, n)} in year {year}"
            )

        stop = start + n
        resp.iloc[start:stop, start:stop] = block
        start = stop
    return resp

resp = {cat: build_block_diagonal_resp(cov[cat], cat) for cat in CAT}

# %%
fisher_cat = {}

# Build the union of all row/column labels
all_rows = list(resp["cat2"].index)
all_cols = list(resp["cat2"].columns)


for cat in CAT:
    r = resp[cat]
    fisher_cat[cat] = r.T @ invert_matrix(cov[cat]) @ r # Without regularization of the covariance matrix before inversion
    # fisher_cat[cat] = r.T @ invert_matrix(tikhonov_regularize_for_inversion(cov[cat])[0]) @ r # With Tikhonov regularization before inversion

# ## Correlations per category
# cov_gen_cat_0 = invert_matrix(fisher_cat["cat0"])
# cov_gen_cat_1 = invert_matrix(fisher_cat["cat1"])
# cov_gen_cat_2 = invert_matrix(fisher_cat["cat2"])
# corr_gen_cat_0 = compute_corr(cov_gen_cat_0)
# corr_gen_cat_1 = compute_corr(cov_gen_cat_1)
# corr_gen_cat_2 = compute_corr(cov_gen_cat_2)

# ## Correlations per category using the formula without inversion of the correlation matrix
# cov_gen_noinv_cat_0 = invert_matrix(resp['cat0']) @ cov["cat0"] @ invert_matrix(resp['cat0']).T
# cov_gen_noinv_cat_1 = invert_matrix(resp['cat1']) @ cov["cat1"] @ invert_matrix(resp['cat1']).T
# cov_gen_noinv_cat_2 = invert_matrix(resp['cat2']) @ cov["cat2"] @ invert_matrix(resp['cat2']).T
# corr_gen_noinv_cat_0 = compute_corr(cov_gen_noinv_cat_0)
# corr_gen_noinv_cat_1 = compute_corr(cov_gen_noinv_cat_1)
# corr_gen_noinv_cat_2 = compute_corr(cov_gen_noinv_cat_2)

result = fisher_cat['cat2'].add(fisher_cat['cat1'], fill_value=0).add(fisher_cat['cat0'], fill_value=0)

## Correlations summing the three categories
cov_gen = invert_matrix(result)
# cov_gen = invert_matrix(tikhonov_regularize_for_inversion(fisher_cat["cat0"] + fisher_cat["cat1"] + fisher_cat["cat2"]))
cov_gen = pd.DataFrame(
    cov_gen,
    index=all_rows,
    columns=all_cols,
)

corr_gen = compute_corr(cov_gen)

####################################################################################################
# Checking the condition number of the various matrices
print("Covariance cat0: ", np.linalg.cond(cov["cat0"]), np.linalg.det(cov["cat0"]))
print("Covariance cat1: ", np.linalg.cond(cov["cat1"]), np.linalg.det(cov["cat1"]))
print("Covariance cat2: ", np.linalg.cond(cov["cat2"]), np.linalg.det(cov["cat2"]))
print("Response cat0: ", np.linalg.cond(resp["cat0"]), np.linalg.det(resp["cat0"]))
print("Response cat1: ", np.linalg.cond(resp["cat1"]), np.linalg.det(resp["cat1"]))
print("Response cat2: ", np.linalg.cond(resp["cat2"]), np.linalg.det(resp["cat2"]))
print("Sum of Fisher matrices: ", np.linalg.cond(result), np.linalg.det(result))
# Out:
# Covariance cat0:  9710.181973015722 5.901760538551436e+120
# Covariance cat1:  19625.04512769982 4.944871955092167e+130
# Covariance cat2:  38212.18103635799 1.8742567290946172e+135
# Response cat0:  245.55058091321962 2.735597327353177e-85
# Response cat1:  621.2369762268281 1.4932949423693122e-81
# Response cat2:  456.63834340559947 9.175491808815861e-83
# Sum of Fisher matrices:  28544.2750464436 2.5174590720767194e-278

# %%
def tikhonov_regularize_for_inversion(
    mat_df: pd.DataFrame,
    alpha_rel: float = 1e-5,
    symmetrize: bool = True
    ):
    A = mat_df.to_numpy(dtype=float)
    if A.shape[0] != A.shape[1]:
        raise ValueError("Input matrix must be square.")
    if symmetrize:
        A = 0.5 * (A + A.T)
    # Estimate a good lambda
    lambda_reg = alpha_rel * np.trace(A) / A.shape[0]  # scaled to mean diagonal

    # Regularize and invert
    A_reg = A + lambda_reg * np.eye(A.shape[0])
    # A_inv = np.linalg.inv(A_reg)
    A_reg = pd.DataFrame(A_reg, index=mat_df.index, columns=mat_df.columns)
    return A_reg

# %%
# plot_corr(corr_gen_cat_0)
# plot_corr(corr_gen_noinv_cat_0)
# print("--------------------------------")
# plot_corr(corr_gen_cat_1)
# plot_corr(corr_gen_noinv_cat_1)
# print("--------------------------------")
# plot_corr(corr_gen_cat_2)
# plot_corr(corr_gen_noinv_cat_2)
# print("--------------------------------")
plot_corr(corr_gen)

# %% [markdown]
# Here I try the great idea we had with Mauro, combining the covariance and response matrices

# %%
## Compute the combined response matrix
## It is done by combining the covariance matrices of three independent measurements 
## cov_weighed = (cov["cat0"]^-1 + cov["cat1"]^-1 + cov["cat2"]^-1)^-1
cov_weighed = invert_matrix(invert_matrix(cov["cat0"]).add(invert_matrix(cov["cat1"]), fill_value=0).add(invert_matrix(cov["cat2"]), fill_value=0))
# plot_corr(corr_from_cov(cov_weighed))
# ## Compute the combined response matrix
# ## It is done by taking the weighed average element by element of the three response matrices
# ## The weights correspond to the corresponding covariances
cats = ["cat0", "cat1", "cat2"]
# R = np.stack([np.asarray(resp[c], float) for c in cats])   
# V = np.stack([np.asarray(cov[c],  float) for c in cats])   
# w = 1.0 / np.clip(V, 1e-15, None)                         
# resp_combined = np.sum(w * R, axis=0) / np.sum(w, axis=0)
# resp_combined = pd.DataFrame(resp_combined, index=resp["cat0"].index, columns=resp["cat0"].columns)


# Build the union of all row/column labels
all_rows = list(resp["cat0"].index)
all_cols = list(resp["cat0"].columns)

# Align all matrices to the same shape
R = np.stack([
    resp[c].reindex(index=all_rows, columns=all_cols, fill_value=0).to_numpy(float)
    for c in cats
])

V = np.stack([
    cov[c].reindex(index=all_rows, columns=all_cols, fill_value=np.inf).to_numpy(float)
    for c in cats
])

# Inverse-variance weights
w = 1.0 / np.clip(V, 1e-15, None)

# Weighted average
resp_combined = np.sum(w * R, axis=0) / np.sum(w, axis=0)

# Convert back to DataFrame
resp_combined = pd.DataFrame(
    resp_combined,
    index=all_rows,
    columns=all_cols,
)
print(np.linalg.cond(resp_combined))

cov_gen_weighed = invert_matrix(resp_combined) @ cov_weighed @ invert_matrix(resp_combined).T

print(all_rows)

plot_corr(corr_from_cov(cov_gen_weighed))
# Out:
# 366.19144223164994
# ['pth_bin0', 'pth_bin1', 'pth_bin2', 'pth_bin3', 'pth_bin4', 'pth_bin5', 'pth_bin6', 'pth_bin7', 'pth_bin8', 'pth_bin9', 'pth_bin10', 'pth_bin11', 'pth_bin12', 'pth_bin13', 'pth_bin14', 'pth_bin15', 'pth_bin16', 'pth_bin17', 'pth_bin18', 'nj_bin0', 'nj_bin1', 'nj_bin2', 'nj_bin3', 'nj_bin4', 'ptj0_bin0', 'ptj0_bin1', 'ptj0_bin2', 'ptj0_bin3', 'ptj0_bin4', 'ptj0_bin5', 'ptj0_bin6', 'ptj0_bin7', 'ptj0_bin8']

# %%
def _robust_cholesky(C, regularisation=1e-10, max_tries=8):
    C = np.asarray(C, dtype=float)
    C = 0.5 * (C + C.T)  # enforce symmetry
    scale = max(np.linalg.norm(C, ord=2), 1.0)
    eps = regularisation * scale
    I = np.eye(C.shape[0])
    for _ in range(max_tries):
        print("iteration for cholesky with eps = ", eps)
        try:
            return np.linalg.cholesky(C + eps * I), eps
        except np.linalg.LinAlgError:
            eps *= 10.0
    print("Fallback solution for computing the Cholesky decomposition")
    # Fallback: eigenvalue clipping to nearest SPD-like matrix
    w, v = np.linalg.eigh(C)
    w = np.clip(w, eps, None)
    C_spd = (v * w) @ v.T
    return np.linalg.cholesky(C_spd), eps


# def compute_C_gen(R_list, C_list, bin_names=None, regularisation=1e-10):
#     """
#     Compute the gen-level statistical covariance and correlation matrices.

#     Parameters
#     ----------
#     R_list         : list of K arrays, each (n_reco_k, n_gen)
#     C_list         : list of K arrays, each (n_reco_k, n_reco_k)
#     bin_names      : list of n_gen strings for row/column labels (optional)
#     regularisation : float, diagonal loading factor (default 1e-10)

#     Returns
#     -------
#     dict with keys:
#         "covariance"   : pd.DataFrame (n_gen x n_gen)
#         "correlation"  : pd.DataFrame (n_gen x n_gen)
#     """

#     R_tilde_list = []
#     for k, (R_k, C_k) in enumerate(zip(R_list, C_list)):
#         # L_k = np.linalg.cholesky(C_k)
#         L_k, eps_used = _robust_cholesky(C_k, regularisation=regularisation)
#         R_tilde_list.append(solve_triangular(L_k, np.asarray(R_k, float), lower=True))

#     R_tot   = np.vstack(R_tilde_list)
#     _, R_QR = qr(R_tot, mode='economic')

#     n_gen    = R_QR.shape[0]
#     R_QR_inv = solve_triangular(R_QR, np.eye(n_gen), lower=False)
#     C_gen    = R_QR_inv @ R_QR_inv.T

#     std  = np.sqrt(np.diag(C_gen))
#     corr = np.clip(C_gen / np.outer(std, std), -1.0, 1.0)

#     # Build labels
#     if bin_names is None:
#         bin_names = [f"bin{i}" for i in range(n_gen)]

#     return {
#         "covariance"  : pd.DataFrame(C_gen, index=bin_names, columns=bin_names),
#         "correlation" : pd.DataFrame(corr,  index=bin_names, columns=bin_names),
#     }

def compute_C_gen(R_list, C_list, bin_names=None, regularisation=1e-10):
    """
    Compute the gen-level statistical covariance and correlation matrices.

    Parameters
    ----------
    R_list         : list of response matrices (DataFrames or arrays)
                     each shaped (n_reco_k, n_gen_k)
    C_list         : list of reco covariance matrices
                     each shaped (n_reco_k, n_reco_k)
    bin_names      : optional ordered list of gen-bin labels
    regularisation : float, diagonal loading factor

    Returns
    -------
    dict with keys:
        "covariance"   : pd.DataFrame
        "correlation"  : pd.DataFrame
    """

    # ---------------------------------------------------------
    # Determine common gen-bin ordering
    # Preserve ordering from first matrix, append missing bins
    # ---------------------------------------------------------

    if isinstance(R_list[0], pd.DataFrame):
        all_gen_bins = list(R_list[0].columns)

        for R in R_list[1:]:
            for col in R.columns:
                if col not in all_gen_bins:
                    all_gen_bins.append(col)
    else:
        if bin_names is None:
            raise ValueError(
                "bin_names must be provided when R_list elements are not DataFrames"
            )
        all_gen_bins = list(bin_names)

    # ---------------------------------------------------------
    # Build whitened response matrices
    # ---------------------------------------------------------

    R_tilde_list = []

    for k, (R_k, C_k) in enumerate(zip(R_list, C_list)):

        # ---------------------------------------------
        # Align response matrix columns
        # Missing bins are filled with zeros
        # ---------------------------------------------

        if isinstance(R_k, pd.DataFrame):
            R_k = (
                R_k
                .reindex(columns=all_gen_bins, fill_value=0)
                .to_numpy(float)
            )
        else:
            R_k = np.asarray(R_k, float)

        # ---------------------------------------------
        # Convert covariance matrix
        # ---------------------------------------------

        if isinstance(C_k, pd.DataFrame):
            C_k = C_k.to_numpy(float)
        else:
            C_k = np.asarray(C_k, float)

        # ---------------------------------------------
        # Robust Cholesky whitening
        # ---------------------------------------------

        L_k, eps_used = _robust_cholesky(
            C_k,
            regularisation=regularisation
        )

        R_tilde_k = solve_triangular(
            L_k,
            R_k,
            lower=True
        )

        R_tilde_list.append(R_tilde_k)

    # ---------------------------------------------------------
    # Stack all categories
    # Shape: (sum reco bins, n_gen_total)
    # ---------------------------------------------------------

    R_tot = np.vstack(R_tilde_list)

    # ---------------------------------------------------------
    # QR decomposition
    # ---------------------------------------------------------

    _, R_QR = qr(R_tot, mode='economic')

    n_gen = R_QR.shape[0]

    # ---------------------------------------------------------
    # Compute covariance
    # ---------------------------------------------------------

    R_QR_inv = solve_triangular(
        R_QR,
        np.eye(n_gen),
        lower=False
    )

    C_gen = R_QR_inv @ R_QR_inv.T

    # ---------------------------------------------------------
    # Correlation matrix
    # ---------------------------------------------------------

    std = np.sqrt(np.diag(C_gen))

    corr = np.clip(
        C_gen / np.outer(std, std),
        -1.0,
        1.0
    )

    # ---------------------------------------------------------
    # Labels
    # ---------------------------------------------------------

    if bin_names is None:
        bin_names = all_gen_bins

    return {
        "covariance": pd.DataFrame(
            C_gen,
            index=bin_names,
            columns=bin_names
        ),

        "correlation": pd.DataFrame(
            corr,
            index=bin_names,
            columns=bin_names
        ),
    }

# %%
mat_cholesky = compute_C_gen(
    [resp["cat0"], resp["cat1"], resp["cat2"]],
    [cov["cat0"], cov["cat1"], cov["cat2"]],
    bin_names = cov["cat0"].index,
    regularisation=1e-10 # 1e-10
)
# Out:
# iteration for cholesky with eps =  2.9495934123645048e-05
# iteration for cholesky with eps =  6.430136958972041e-05
# iteration for cholesky with eps =  0.000643013695897204
# iteration for cholesky with eps =  0.00643013695897204
# iteration for cholesky with eps =  0.06430136958972041
# iteration for cholesky with eps =  0.6430136958972041
# iteration for cholesky with eps =  6.430136958972041
# iteration for cholesky with eps =  64.30136958972041
# iteration for cholesky with eps =  643.0136958972041
# iteration for cholesky with eps =  0.00010463935477599568

# %%
cor_cholesky = mat_cholesky["correlation"]
label_to_drop = cor_cholesky.index[12]
cor_cholesky_red = cor_cholesky.drop(index=label_to_drop, columns=label_to_drop)

# %%
plot_corr(cor_cholesky_red, title="Correlation matrix (Cholesky)", save_path="correlation_matrix_cholesky_reduced.pdf", label_map=label_map)
# plot_corr(cor_cholesky, title="Correlation matrix (Cholesky)", save_path="correlation_matrix_cholesky_reduced.pdf", label_map=label_map)

# %% [markdown]
# ### Adding systematic uncertainties

# %%
with open ("/t3home/niharrin/devel/work/devel/RCR_Matrix/impacts/impacts_PTJ0.json", "r") as f:
    impacts_ptJ0 = json.load(f)

with open ("/t3home/niharrin/devel/work/devel/RCR_Matrix/impacts/impacts_PTH.json", "r") as f:
    impacts_PTH = json.load(f)

with open ("/t3home/niharrin/devel/work/devel/RCR_Matrix/impacts/impacts_NJ.json", "r") as f:
    impacts_NJ = json.load(f)

with open ("/t3home/niharrin/devel/work/devel/RCR_Matrix/impacts/impacts_YH.json", "r") as f:
    impacts_YH = json.load(f)

# %%
nuis_params = set()
# Printout the list of nuisance parameters
# For debugging purposes
# with open("impact_param_names.txt", "w") as f:
#   f.write("[PTH]\n")
#   f.writelines(p["name"] + "\n" for p in impacts_PTH["params"])
#   f.write("\n[NJ]\n")
#   f.writelines(p["name"] + "\n" for p in impacts_NJ["params"])
#   f.write("\n[ptJ0]\n")
#   f.writelines(p["name"] + "\n" for p in impacts_ptJ0["params"])
#   f.write("\n[YH]\n")
#   f.writelines(p["name"] + "\n" for p in impacts_YH["params"])

sections = {
    "PTH": impacts_PTH,
    "NJ": impacts_NJ,
    "ptJ0": impacts_ptJ0,
    # "YH": impacts_YH,
}

with open("impact_param_names.txt", "w") as f:
    for label, impacts in sections.items():
        f.write(f"[{label}]\n")

        for p in impacts.get("params", []):
            name = p.get("name", "")
            f.write(name + "\n")
            nuis_params.add(name)

        f.write("\n")

nuis_params = sorted(nuis_params)  # optional: deterministic order

# %%
nuis_params
# Out:
# ['CMS_hgg_AlphaS_shape',
#  'CMS_hgg_ElectronVetoSF_2022postEE',
#  'CMS_hgg_ElectronVetoSF_2022preEE',
#  'CMS_hgg_ElectronVetoSF_2023postBPix',
#  'CMS_hgg_ElectronVetoSF_2023preBPix',
#  'CMS_hgg_ElectronVetoSF_2024',
#  'CMS_hgg_PS_FSR_shape',
#  'CMS_hgg_PS_ISR_shape',
#  'CMS_hgg_PileupWeight',
#  'CMS_hgg_PreselSF',
#  'CMS_hgg_SigmaEOverEShift',
#  'CMS_hgg_TriggerWeight',
#  'CMS_hgg_nuisance_ScaleEBZee_2022postEE',
#  'CMS_hgg_nuisance_ScaleEBZee_2022preEE',
#  'CMS_hgg_nuisance_ScaleEBZee_2023postBPix',
#  'CMS_hgg_nuisance_ScaleEBZee_2023preBPix',
#  'CMS_hgg_nuisance_ScaleEBZee_2024',
#  'CMS_hgg_nuisance_ScaleEBZmmg_2022_2023',
#  'CMS_hgg_nuisance_ScaleEBZmmg_2024',
#  'CMS_hgg_nuisance_ScaleEEZee_2022postEE',
#  'CMS_hgg_nuisance_ScaleEEZee_2022preEE',
#  'CMS_hgg_nuisance_ScaleEEZee_2023postBPix',
#  'CMS_hgg_nuisance_ScaleEEZee_2023preBPix',
#  'CMS_hgg_nuisance_ScaleEEZee_2024',
#  'CMS_hgg_nuisance_ScaleEEZmmg_2022_2023',
#  'CMS_hgg_nuisance_ScaleEEZmmg_2024',
#  'CMS_hgg_nuisance_Smearing_2022postEE',
#  'CMS_hgg_nuisance_Smearing_2022preEE',
#  'CMS_hgg_nuisance_Smearing_2023postBPix',
#  'CMS_hgg_nuisance_Smearing_2023preBPix',
#  'CMS_hgg_nuisance_Smearing_2024',
#  'CMS_hgg_nuisance_deltafracright',
#  'CMS_hgg_pdfWeight_10_shape',
#  'CMS_hgg_pdfWeight_11_shape',
#  'CMS_hgg_pdfWeight_12_shape',
#  'CMS_hgg_pdfWeight_13_shape',
#  'CMS_hgg_pdfWeight_14_shape',
#  'CMS_hgg_pdfWeight_15_shape',
#  'CMS_hgg_pdfWeight_16_shape',
#  'CMS_hgg_pdfWeight_17_shape',
#  'CMS_hgg_pdfWeight_18_shape',
#  'CMS_hgg_pdfWeight_19_shape',
#  'CMS_hgg_pdfWeight_1_shape',
#  'CMS_hgg_pdfWeight_20_shape',
#  'CMS_hgg_pdfWeight_21_shape',
#  'CMS_hgg_pdfWeight_22_shape',
#  'CMS_hgg_pdfWeight_23_shape',
#  'CMS_hgg_pdfWeight_24_shape',
#  'CMS_hgg_pdfWeight_25_shape',
#  'CMS_hgg_pdfWeight_26_shape',
#  'CMS_hgg_pdfWeight_27_shape',
#  'CMS_hgg_pdfWeight_28_shape',
#  'CMS_hgg_pdfWeight_29_shape',
#  'CMS_hgg_pdfWeight_2_shape',
#  'CMS_hgg_pdfWeight_30_shape',
#  'CMS_hgg_pdfWeight_31_shape',
#  'CMS_hgg_pdfWeight_32_shape',
#  'CMS_hgg_pdfWeight_33_shape',
#  'CMS_hgg_pdfWeight_34_shape',
#  'CMS_hgg_pdfWeight_35_shape',
#  'CMS_hgg_pdfWeight_36_shape',
#  'CMS_hgg_pdfWeight_37_shape',
#  'CMS_hgg_pdfWeight_38_shape',
#  'CMS_hgg_pdfWeight_39_shape',
#  'CMS_hgg_pdfWeight_3_shape',
#  'CMS_hgg_pdfWeight_40_shape',
#  'CMS_hgg_pdfWeight_41_shape',
#  'CMS_hgg_pdfWeight_42_shape',
#  'CMS_hgg_pdfWeight_43_shape',
#  'CMS_hgg_pdfWeight_44_shape',
#  'CMS_hgg_pdfWeight_45_shape',
#  'CMS_hgg_pdfWeight_46_shape',
#  'CMS_hgg_pdfWeight_47_shape',
#  'CMS_hgg_pdfWeight_48_shape',
#  'CMS_hgg_pdfWeight_49_shape',
#  'CMS_hgg_pdfWeight_4_shape',
#  'CMS_hgg_pdfWeight_50_shape',
#  'CMS_hgg_pdfWeight_51_shape',
#  'CMS_hgg_pdfWeight_52_shape',
#  'CMS_hgg_pdfWeight_53_shape',
#  'CMS_hgg_pdfWeight_54_shape',
#  'CMS_hgg_pdfWeight_55_shape',
#  'CMS_hgg_pdfWeight_56_shape',
#  'CMS_hgg_pdfWeight_57_shape',
#  'CMS_hgg_pdfWeight_58_shape',
#  'CMS_hgg_pdfWeight_59_shape',
#  'CMS_hgg_pdfWeight_5_shape',
#  'CMS_hgg_pdfWeight_60_shape',
#  'CMS_hgg_pdfWeight_61_shape',
#  'CMS_hgg_pdfWeight_62_shape',
#  'CMS_hgg_pdfWeight_63_shape',
#  'CMS_hgg_pdfWeight_64_shape',
#  'CMS_hgg_pdfWeight_65_shape',
#  'CMS_hgg_pdfWeight_66_shape',
#  'CMS_hgg_pdfWeight_67_shape',
#  'CMS_hgg_pdfWeight_68_shape',
#  'CMS_hgg_pdfWeight_69_shape',
#  'CMS_hgg_pdfWeight_6_shape',
#  'CMS_hgg_pdfWeight_70_shape',
#  'CMS_hgg_pdfWeight_71_shape',
#  'CMS_hgg_pdfWeight_72_shape',
#  'CMS_hgg_pdfWeight_73_shape',
#  'CMS_hgg_pdfWeight_74_shape',
#  'CMS_hgg_pdfWeight_75_shape',
#  'CMS_hgg_pdfWeight_76_shape',
#  'CMS_hgg_pdfWeight_77_shape',
#  'CMS_hgg_pdfWeight_78_shape',
#  'CMS_hgg_pdfWeight_79_shape',
#  'CMS_hgg_pdfWeight_7_shape',
#  'CMS_hgg_pdfWeight_80_shape',
#  'CMS_hgg_pdfWeight_81_shape',
#  'CMS_hgg_pdfWeight_82_shape',
#  'CMS_hgg_pdfWeight_83_shape',
#  'CMS_hgg_pdfWeight_84_shape',
#  'CMS_hgg_pdfWeight_85_shape',
#  'CMS_hgg_pdfWeight_86_shape',
#  'CMS_hgg_pdfWeight_87_shape',
#  'CMS_hgg_pdfWeight_88_shape',
#  'CMS_hgg_pdfWeight_89_shape',
#  'CMS_hgg_pdfWeight_8_shape',
#  'CMS_hgg_pdfWeight_90_shape',
#  'CMS_hgg_pdfWeight_91_shape',
#  'CMS_hgg_pdfWeight_92_shape',
#  'CMS_hgg_pdfWeight_93_shape',
#  'CMS_hgg_pdfWeight_94_shape',
#  'CMS_hgg_pdfWeight_95_shape',
#  'CMS_hgg_pdfWeight_96_shape',
#  'CMS_hgg_pdfWeight_97_shape',
#  'CMS_hgg_pdfWeight_98_shape',
#  'CMS_hgg_pdfWeight_99_shape',
#  'CMS_hgg_pdfWeight_9_shape',
#  'CMS_hgg_phoIdMva',
#  'CMS_hgg_scale_0_shape',
#  'CMS_hgg_scale_1_shape',
#  'CMS_hgg_scale_3_shape',
#  'CMS_res_j_2022postEE',
#  'CMS_res_j_2022preEE',
#  'CMS_res_j_2023postBPix',
#  'CMS_res_j_2023preBPix',
#  'CMS_res_j_2024',
#  'CMS_scale_j_2022postEE',
#  'CMS_scale_j_2022preEE',
#  'CMS_scale_j_2023postBPix',
#  'CMS_scale_j_2023preBPix',
#  'CMS_scale_j_2024',
#  'MCStat_2022postEE_RECO_NJ_0p0_1p0_cat0',
#  'MCStat_2022postEE_RECO_NJ_0p0_1p0_cat1',
#  'MCStat_2022postEE_RECO_NJ_0p0_1p0_cat2',
#  'MCStat_2022postEE_RECO_NJ_1p0_2p0_cat0',
#  'MCStat_2022postEE_RECO_NJ_1p0_2p0_cat1',
#  'MCStat_2022postEE_RECO_NJ_1p0_2p0_cat2',
#  'MCStat_2022postEE_RECO_NJ_2p0_3p0_cat0',
#  'MCStat_2022postEE_RECO_NJ_2p0_3p0_cat1',
#  'MCStat_2022postEE_RECO_NJ_2p0_3p0_cat2',
#  'MCStat_2022postEE_RECO_NJ_3p0_4p0_cat0',
#  'MCStat_2022postEE_RECO_NJ_3p0_4p0_cat1',
#  'MCStat_2022postEE_RECO_NJ_3p0_4p0_cat2',
#  'MCStat_2022postEE_RECO_NJ_4p0_100p0_cat0',
#  'MCStat_2022postEE_RECO_NJ_4p0_100p0_cat1',
#  'MCStat_2022postEE_RECO_NJ_4p0_100p0_cat2',
#  'MCStat_2022postEE_RECO_PTH_0p0_5p0_cat0',
#  'MCStat_2022postEE_RECO_PTH_0p0_5p0_cat1',
#  'MCStat_2022postEE_RECO_PTH_0p0_5p0_cat2',
#  'MCStat_2022postEE_RECO_PTH_100p0_120p0_cat0',
#  'MCStat_2022postEE_RECO_PTH_100p0_120p0_cat1',
#  'MCStat_2022postEE_RECO_PTH_100p0_120p0_cat2',
#  'MCStat_2022postEE_RECO_PTH_10p0_15p0_cat0',
#  'MCStat_2022postEE_RECO_PTH_10p0_15p0_cat1',
#  'MCStat_2022postEE_RECO_PTH_10p0_15p0_cat2',
#  'MCStat_2022postEE_RECO_PTH_120p0_140p0_cat0',
#  'MCStat_2022postEE_RECO_PTH_120p0_140p0_cat1',
#  'MCStat_2022postEE_RECO_PTH_120p0_140p0_cat2',
#  'MCStat_2022postEE_RECO_PTH_140p0_170p0_cat0',
#  'MCStat_2022postEE_RECO_PTH_140p0_170p0_cat1',
#  'MCStat_2022postEE_RECO_PTH_140p0_170p0_cat2',
#  'MCStat_2022postEE_RECO_PTH_15p0_20p0_cat0',
#  'MCStat_2022postEE_RECO_PTH_15p0_20p0_cat1',
#  'MCStat_2022postEE_RECO_PTH_15p0_20p0_cat2',
#  'MCStat_2022postEE_RECO_PTH_170p0_200p0_cat0',
#  'MCStat_2022postEE_RECO_PTH_170p0_200p0_cat1',
#  'MCStat_2022postEE_RECO_PTH_170p0_200p0_cat2',
#  'MCStat_2022postEE_RECO_PTH_200p0_250p0_cat0',
#  'MCStat_2022postEE_RECO_PTH_200p0_250p0_cat1',
#  'MCStat_2022postEE_RECO_PTH_200p0_250p0_cat2',
#  'MCStat_2022postEE_RECO_PTH_20p0_25p0_cat0',
#  'MCStat_2022postEE_RECO_PTH_20p0_25p0_cat1',
#  'MCStat_2022postEE_RECO_PTH_20p0_25p0_cat2',
#  'MCStat_2022postEE_RECO_PTH_250p0_350p0_cat0',
#  'MCStat_2022postEE_RECO_PTH_250p0_350p0_cat1',
#  'MCStat_2022postEE_RECO_PTH_250p0_350p0_cat2',
#  'MCStat_2022postEE_RECO_PTH_25p0_30p0_cat0',
#  'MCStat_2022postEE_RECO_PTH_25p0_30p0_cat1',
#  'MCStat_2022postEE_RECO_PTH_25p0_30p0_cat2',
#  'MCStat_2022postEE_RECO_PTH_30p0_35p0_cat0',
#  'MCStat_2022postEE_RECO_PTH_30p0_35p0_cat1',
#  'MCStat_2022postEE_RECO_PTH_30p0_35p0_cat2',
#  'MCStat_2022postEE_RECO_PTH_350p0_450p0_cat0',
#  'MCStat_2022postEE_RECO_PTH_350p0_450p0_cat1',
#  'MCStat_2022postEE_RECO_PTH_350p0_450p0_cat2',
#  'MCStat_2022postEE_RECO_PTH_35p0_45p0_cat0',
#  'MCStat_2022postEE_RECO_PTH_35p0_45p0_cat1',
#  'MCStat_2022postEE_RECO_PTH_35p0_45p0_cat2',
#  'MCStat_2022postEE_RECO_PTH_450p0_10000p0_catMerged',
#  'MCStat_2022postEE_RECO_PTH_45p0_60p0_cat0',
#  'MCStat_2022postEE_RECO_PTH_45p0_60p0_cat1',
#  'MCStat_2022postEE_RECO_PTH_45p0_60p0_cat2',
#  'MCStat_2022postEE_RECO_PTH_5p0_10p0_cat0',
#  'MCStat_2022postEE_RECO_PTH_5p0_10p0_cat1',
#  'MCStat_2022postEE_RECO_PTH_5p0_10p0_cat2',
#  'MCStat_2022postEE_RECO_PTH_60p0_80p0_cat0',
#  'MCStat_2022postEE_RECO_PTH_60p0_80p0_cat1',
#  'MCStat_2022postEE_RECO_PTH_60p0_80p0_cat2',
#  'MCStat_2022postEE_RECO_PTH_80p0_100p0_cat0',
#  'MCStat_2022postEE_RECO_PTH_80p0_100p0_cat1',
#  'MCStat_2022postEE_RECO_PTH_80p0_100p0_cat2',
#  'MCStat_2022postEE_RECO_PTJ0_120p0_150p0_cat0',
#  'MCStat_2022postEE_RECO_PTJ0_120p0_150p0_cat1',
#  'MCStat_2022postEE_RECO_PTJ0_120p0_150p0_cat2',
#  'MCStat_2022postEE_RECO_PTJ0_150p0_200p0_cat0',
#  'MCStat_2022postEE_RECO_PTJ0_150p0_200p0_cat1',
#  'MCStat_2022postEE_RECO_PTJ0_150p0_200p0_cat2',
#  'MCStat_2022postEE_RECO_PTJ0_200p0_10000p0_cat0',
#  'MCStat_2022postEE_RECO_PTJ0_200p0_10000p0_cat1',
#  'MCStat_2022postEE_RECO_PTJ0_200p0_10000p0_cat2',
#  'MCStat_2022postEE_RECO_PTJ0_30p0_40p0_cat0',
#  'MCStat_2022postEE_RECO_PTJ0_30p0_40p0_cat1',
#  'MCStat_2022postEE_RECO_PTJ0_30p0_40p0_cat2',
#  'MCStat_2022postEE_RECO_PTJ0_40p0_55p0_cat0',
#  'MCStat_2022postEE_RECO_PTJ0_40p0_55p0_cat1',
#  'MCStat_2022postEE_RECO_PTJ0_40p0_55p0_cat2',
#  'MCStat_2022postEE_RECO_PTJ0_55p0_75p0_cat0',
#  'MCStat_2022postEE_RECO_PTJ0_55p0_75p0_cat1',
#  'MCStat_2022postEE_RECO_PTJ0_55p0_75p0_cat2',
#  'MCStat_2022postEE_RECO_PTJ0_75p0_95p0_cat0',
#  'MCStat_2022postEE_RECO_PTJ0_75p0_95p0_cat1',
#  'MCStat_2022postEE_RECO_PTJ0_75p0_95p0_cat2',
#  'MCStat_2022postEE_RECO_PTJ0_95p0_120p0_cat0',
#  'MCStat_2022postEE_RECO_PTJ0_95p0_120p0_cat1',
#  'MCStat_2022postEE_RECO_PTJ0_95p0_120p0_cat2',
#  'MCStat_2022postEE_RECO_PTJ0_m10000p0_30p0_cat0',
#  'MCStat_2022postEE_RECO_PTJ0_m10000p0_30p0_cat1',
#  'MCStat_2022postEE_RECO_PTJ0_m10000p0_30p0_cat2',
#  'MCStat_2022preEE_RECO_NJ_0p0_1p0_cat0',
#  'MCStat_2022preEE_RECO_NJ_0p0_1p0_cat1',
#  'MCStat_2022preEE_RECO_NJ_0p0_1p0_cat2',
#  'MCStat_2022preEE_RECO_NJ_1p0_2p0_cat0',
#  'MCStat_2022preEE_RECO_NJ_1p0_2p0_cat1',
#  'MCStat_2022preEE_RECO_NJ_1p0_2p0_cat2',
#  'MCStat_2022preEE_RECO_NJ_2p0_3p0_cat0',
#  'MCStat_2022preEE_RECO_NJ_2p0_3p0_cat1',
#  'MCStat_2022preEE_RECO_NJ_2p0_3p0_cat2',
#  'MCStat_2022preEE_RECO_NJ_3p0_4p0_cat0',
#  'MCStat_2022preEE_RECO_NJ_3p0_4p0_cat1',
#  'MCStat_2022preEE_RECO_NJ_3p0_4p0_cat2',
#  'MCStat_2022preEE_RECO_NJ_4p0_100p0_cat0',
#  'MCStat_2022preEE_RECO_NJ_4p0_100p0_cat1',
#  'MCStat_2022preEE_RECO_NJ_4p0_100p0_cat2',
#  'MCStat_2022preEE_RECO_PTH_0p0_5p0_cat0',
#  'MCStat_2022preEE_RECO_PTH_0p0_5p0_cat1',
#  'MCStat_2022preEE_RECO_PTH_0p0_5p0_cat2',
#  'MCStat_2022preEE_RECO_PTH_100p0_120p0_cat0',
#  'MCStat_2022preEE_RECO_PTH_100p0_120p0_cat1',
#  'MCStat_2022preEE_RECO_PTH_100p0_120p0_cat2',
#  'MCStat_2022preEE_RECO_PTH_10p0_15p0_cat0',
#  'MCStat_2022preEE_RECO_PTH_10p0_15p0_cat1',
#  'MCStat_2022preEE_RECO_PTH_10p0_15p0_cat2',
#  'MCStat_2022preEE_RECO_PTH_120p0_140p0_cat0',
#  'MCStat_2022preEE_RECO_PTH_120p0_140p0_cat1',
#  'MCStat_2022preEE_RECO_PTH_120p0_140p0_cat2',
#  'MCStat_2022preEE_RECO_PTH_140p0_170p0_cat0',
#  'MCStat_2022preEE_RECO_PTH_140p0_170p0_cat1',
#  'MCStat_2022preEE_RECO_PTH_140p0_170p0_cat2',
#  'MCStat_2022preEE_RECO_PTH_15p0_20p0_cat0',
#  'MCStat_2022preEE_RECO_PTH_15p0_20p0_cat1',
#  'MCStat_2022preEE_RECO_PTH_15p0_20p0_cat2',
#  'MCStat_2022preEE_RECO_PTH_170p0_200p0_cat0',
#  'MCStat_2022preEE_RECO_PTH_170p0_200p0_cat1',
#  'MCStat_2022preEE_RECO_PTH_170p0_200p0_cat2',
#  'MCStat_2022preEE_RECO_PTH_200p0_250p0_cat0',
#  'MCStat_2022preEE_RECO_PTH_200p0_250p0_cat1',
#  'MCStat_2022preEE_RECO_PTH_200p0_250p0_cat2',
#  'MCStat_2022preEE_RECO_PTH_20p0_25p0_cat0',
#  'MCStat_2022preEE_RECO_PTH_20p0_25p0_cat1',
#  'MCStat_2022preEE_RECO_PTH_20p0_25p0_cat2',
#  'MCStat_2022preEE_RECO_PTH_250p0_350p0_cat0',
#  'MCStat_2022preEE_RECO_PTH_250p0_350p0_cat1',
#  'MCStat_2022preEE_RECO_PTH_250p0_350p0_cat2',
#  'MCStat_2022preEE_RECO_PTH_25p0_30p0_cat0',
#  'MCStat_2022preEE_RECO_PTH_25p0_30p0_cat1',
#  'MCStat_2022preEE_RECO_PTH_25p0_30p0_cat2',
#  'MCStat_2022preEE_RECO_PTH_30p0_35p0_cat0',
#  'MCStat_2022preEE_RECO_PTH_30p0_35p0_cat1',
#  'MCStat_2022preEE_RECO_PTH_30p0_35p0_cat2',
#  'MCStat_2022preEE_RECO_PTH_350p0_450p0_cat0',
#  'MCStat_2022preEE_RECO_PTH_350p0_450p0_cat1',
#  'MCStat_2022preEE_RECO_PTH_350p0_450p0_cat2',
#  'MCStat_2022preEE_RECO_PTH_35p0_45p0_cat0',
#  'MCStat_2022preEE_RECO_PTH_35p0_45p0_cat1',
#  'MCStat_2022preEE_RECO_PTH_35p0_45p0_cat2',
#  'MCStat_2022preEE_RECO_PTH_450p0_10000p0_catMerged',
#  'MCStat_2022preEE_RECO_PTH_45p0_60p0_cat0',
#  'MCStat_2022preEE_RECO_PTH_45p0_60p0_cat1',
#  'MCStat_2022preEE_RECO_PTH_45p0_60p0_cat2',
#  'MCStat_2022preEE_RECO_PTH_5p0_10p0_cat0',
#  'MCStat_2022preEE_RECO_PTH_5p0_10p0_cat1',
#  'MCStat_2022preEE_RECO_PTH_5p0_10p0_cat2',
#  'MCStat_2022preEE_RECO_PTH_60p0_80p0_cat0',
#  'MCStat_2022preEE_RECO_PTH_60p0_80p0_cat1',
#  'MCStat_2022preEE_RECO_PTH_60p0_80p0_cat2',
#  'MCStat_2022preEE_RECO_PTH_80p0_100p0_cat0',
#  'MCStat_2022preEE_RECO_PTH_80p0_100p0_cat1',
#  'MCStat_2022preEE_RECO_PTH_80p0_100p0_cat2',
#  'MCStat_2022preEE_RECO_PTJ0_120p0_150p0_cat0',
#  'MCStat_2022preEE_RECO_PTJ0_120p0_150p0_cat1',
#  'MCStat_2022preEE_RECO_PTJ0_120p0_150p0_cat2',
#  'MCStat_2022preEE_RECO_PTJ0_150p0_200p0_cat0',
#  'MCStat_2022preEE_RECO_PTJ0_150p0_200p0_cat1',
#  'MCStat_2022preEE_RECO_PTJ0_150p0_200p0_cat2',
#  'MCStat_2022preEE_RECO_PTJ0_200p0_10000p0_cat0',
#  'MCStat_2022preEE_RECO_PTJ0_200p0_10000p0_cat1',
#  'MCStat_2022preEE_RECO_PTJ0_200p0_10000p0_cat2',
#  'MCStat_2022preEE_RECO_PTJ0_30p0_40p0_cat0',
#  'MCStat_2022preEE_RECO_PTJ0_30p0_40p0_cat1',
#  'MCStat_2022preEE_RECO_PTJ0_30p0_40p0_cat2',
#  'MCStat_2022preEE_RECO_PTJ0_40p0_55p0_cat0',
#  'MCStat_2022preEE_RECO_PTJ0_40p0_55p0_cat1',
#  'MCStat_2022preEE_RECO_PTJ0_40p0_55p0_cat2',
#  'MCStat_2022preEE_RECO_PTJ0_55p0_75p0_cat0',
#  'MCStat_2022preEE_RECO_PTJ0_55p0_75p0_cat1',
#  'MCStat_2022preEE_RECO_PTJ0_55p0_75p0_cat2',
#  'MCStat_2022preEE_RECO_PTJ0_75p0_95p0_cat0',
#  'MCStat_2022preEE_RECO_PTJ0_75p0_95p0_cat1',
#  'MCStat_2022preEE_RECO_PTJ0_75p0_95p0_cat2',
#  'MCStat_2022preEE_RECO_PTJ0_95p0_120p0_cat0',
#  'MCStat_2022preEE_RECO_PTJ0_95p0_120p0_cat1',
#  'MCStat_2022preEE_RECO_PTJ0_95p0_120p0_cat2',
#  'MCStat_2022preEE_RECO_PTJ0_m10000p0_30p0_cat0',
#  'MCStat_2022preEE_RECO_PTJ0_m10000p0_30p0_cat1',
#  'MCStat_2022preEE_RECO_PTJ0_m10000p0_30p0_cat2',
#  'MCStat_2023postBPix_RECO_NJ_0p0_1p0_cat0',
#  'MCStat_2023postBPix_RECO_NJ_0p0_1p0_cat1',
#  'MCStat_2023postBPix_RECO_NJ_0p0_1p0_cat2',
#  'MCStat_2023postBPix_RECO_NJ_1p0_2p0_cat0',
#  'MCStat_2023postBPix_RECO_NJ_1p0_2p0_cat1',
#  'MCStat_2023postBPix_RECO_NJ_1p0_2p0_cat2',
#  'MCStat_2023postBPix_RECO_NJ_2p0_3p0_cat0',
#  'MCStat_2023postBPix_RECO_NJ_2p0_3p0_cat1',
#  'MCStat_2023postBPix_RECO_NJ_2p0_3p0_cat2',
#  'MCStat_2023postBPix_RECO_NJ_3p0_4p0_cat0',
#  'MCStat_2023postBPix_RECO_NJ_3p0_4p0_cat1',
#  'MCStat_2023postBPix_RECO_NJ_3p0_4p0_cat2',
#  'MCStat_2023postBPix_RECO_NJ_4p0_100p0_cat0',
#  'MCStat_2023postBPix_RECO_NJ_4p0_100p0_cat1',
#  'MCStat_2023postBPix_RECO_NJ_4p0_100p0_cat2',
#  'MCStat_2023postBPix_RECO_PTH_0p0_5p0_cat0',
#  'MCStat_2023postBPix_RECO_PTH_0p0_5p0_cat1',
#  'MCStat_2023postBPix_RECO_PTH_0p0_5p0_cat2',
#  'MCStat_2023postBPix_RECO_PTH_100p0_120p0_cat0',
#  'MCStat_2023postBPix_RECO_PTH_100p0_120p0_cat1',
#  'MCStat_2023postBPix_RECO_PTH_100p0_120p0_cat2',
#  'MCStat_2023postBPix_RECO_PTH_10p0_15p0_cat0',
#  'MCStat_2023postBPix_RECO_PTH_10p0_15p0_cat1',
#  'MCStat_2023postBPix_RECO_PTH_10p0_15p0_cat2',
#  'MCStat_2023postBPix_RECO_PTH_120p0_140p0_cat0',
#  'MCStat_2023postBPix_RECO_PTH_120p0_140p0_cat1',
#  'MCStat_2023postBPix_RECO_PTH_120p0_140p0_cat2',
#  'MCStat_2023postBPix_RECO_PTH_140p0_170p0_cat0',
#  'MCStat_2023postBPix_RECO_PTH_140p0_170p0_cat1',
#  'MCStat_2023postBPix_RECO_PTH_140p0_170p0_cat2',
#  'MCStat_2023postBPix_RECO_PTH_15p0_20p0_cat0',
#  'MCStat_2023postBPix_RECO_PTH_15p0_20p0_cat1',
#  'MCStat_2023postBPix_RECO_PTH_15p0_20p0_cat2',
#  'MCStat_2023postBPix_RECO_PTH_170p0_200p0_cat0',
#  'MCStat_2023postBPix_RECO_PTH_170p0_200p0_cat1',
#  'MCStat_2023postBPix_RECO_PTH_170p0_200p0_cat2',
#  'MCStat_2023postBPix_RECO_PTH_200p0_250p0_cat0',
#  'MCStat_2023postBPix_RECO_PTH_200p0_250p0_cat1',
#  'MCStat_2023postBPix_RECO_PTH_200p0_250p0_cat2',
#  'MCStat_2023postBPix_RECO_PTH_20p0_25p0_cat0',
#  'MCStat_2023postBPix_RECO_PTH_20p0_25p0_cat1',
#  'MCStat_2023postBPix_RECO_PTH_20p0_25p0_cat2',
#  'MCStat_2023postBPix_RECO_PTH_250p0_350p0_cat0',
#  'MCStat_2023postBPix_RECO_PTH_250p0_350p0_cat1',
#  'MCStat_2023postBPix_RECO_PTH_250p0_350p0_cat2',
#  'MCStat_2023postBPix_RECO_PTH_25p0_30p0_cat0',
#  'MCStat_2023postBPix_RECO_PTH_25p0_30p0_cat1',
#  'MCStat_2023postBPix_RECO_PTH_25p0_30p0_cat2',
#  'MCStat_2023postBPix_RECO_PTH_30p0_35p0_cat0',
#  'MCStat_2023postBPix_RECO_PTH_30p0_35p0_cat1',
#  'MCStat_2023postBPix_RECO_PTH_30p0_35p0_cat2',
#  'MCStat_2023postBPix_RECO_PTH_350p0_450p0_cat0',
#  'MCStat_2023postBPix_RECO_PTH_350p0_450p0_cat1',
#  'MCStat_2023postBPix_RECO_PTH_350p0_450p0_cat2',
#  'MCStat_2023postBPix_RECO_PTH_35p0_45p0_cat0',
#  'MCStat_2023postBPix_RECO_PTH_35p0_45p0_cat1',
#  'MCStat_2023postBPix_RECO_PTH_35p0_45p0_cat2',
#  'MCStat_2023postBPix_RECO_PTH_450p0_10000p0_catMerged',
#  'MCStat_2023postBPix_RECO_PTH_45p0_60p0_cat0',
#  'MCStat_2023postBPix_RECO_PTH_45p0_60p0_cat1',
#  'MCStat_2023postBPix_RECO_PTH_45p0_60p0_cat2',
#  'MCStat_2023postBPix_RECO_PTH_5p0_10p0_cat0',
#  'MCStat_2023postBPix_RECO_PTH_5p0_10p0_cat1',
#  'MCStat_2023postBPix_RECO_PTH_5p0_10p0_cat2',
#  'MCStat_2023postBPix_RECO_PTH_60p0_80p0_cat0',
#  'MCStat_2023postBPix_RECO_PTH_60p0_80p0_cat1',
#  'MCStat_2023postBPix_RECO_PTH_60p0_80p0_cat2',
#  'MCStat_2023postBPix_RECO_PTH_80p0_100p0_cat0',
#  'MCStat_2023postBPix_RECO_PTH_80p0_100p0_cat1',
#  'MCStat_2023postBPix_RECO_PTH_80p0_100p0_cat2',
#  'MCStat_2023postBPix_RECO_PTJ0_120p0_150p0_cat0',
#  'MCStat_2023postBPix_RECO_PTJ0_120p0_150p0_cat1',
#  'MCStat_2023postBPix_RECO_PTJ0_120p0_150p0_cat2',
#  'MCStat_2023postBPix_RECO_PTJ0_150p0_200p0_cat0',
#  'MCStat_2023postBPix_RECO_PTJ0_150p0_200p0_cat1',
#  'MCStat_2023postBPix_RECO_PTJ0_150p0_200p0_cat2',
#  'MCStat_2023postBPix_RECO_PTJ0_200p0_10000p0_cat0',
#  'MCStat_2023postBPix_RECO_PTJ0_200p0_10000p0_cat1',
#  'MCStat_2023postBPix_RECO_PTJ0_200p0_10000p0_cat2',
#  'MCStat_2023postBPix_RECO_PTJ0_30p0_40p0_cat0',
#  'MCStat_2023postBPix_RECO_PTJ0_30p0_40p0_cat1',
#  'MCStat_2023postBPix_RECO_PTJ0_30p0_40p0_cat2',
#  'MCStat_2023postBPix_RECO_PTJ0_40p0_55p0_cat0',
#  'MCStat_2023postBPix_RECO_PTJ0_40p0_55p0_cat1',
#  'MCStat_2023postBPix_RECO_PTJ0_40p0_55p0_cat2',
#  'MCStat_2023postBPix_RECO_PTJ0_55p0_75p0_cat0',
#  'MCStat_2023postBPix_RECO_PTJ0_55p0_75p0_cat1',
#  'MCStat_2023postBPix_RECO_PTJ0_55p0_75p0_cat2',
#  'MCStat_2023postBPix_RECO_PTJ0_75p0_95p0_cat0',
#  'MCStat_2023postBPix_RECO_PTJ0_75p0_95p0_cat1',
#  'MCStat_2023postBPix_RECO_PTJ0_75p0_95p0_cat2',
#  'MCStat_2023postBPix_RECO_PTJ0_95p0_120p0_cat0',
#  'MCStat_2023postBPix_RECO_PTJ0_95p0_120p0_cat1',
#  'MCStat_2023postBPix_RECO_PTJ0_95p0_120p0_cat2',
#  'MCStat_2023postBPix_RECO_PTJ0_m10000p0_30p0_cat0',
#  'MCStat_2023postBPix_RECO_PTJ0_m10000p0_30p0_cat1',
#  'MCStat_2023postBPix_RECO_PTJ0_m10000p0_30p0_cat2',
#  'MCStat_2023preBPix_RECO_NJ_0p0_1p0_cat0',
#  'MCStat_2023preBPix_RECO_NJ_0p0_1p0_cat1',
#  'MCStat_2023preBPix_RECO_NJ_0p0_1p0_cat2',
#  'MCStat_2023preBPix_RECO_NJ_1p0_2p0_cat0',
#  'MCStat_2023preBPix_RECO_NJ_1p0_2p0_cat1',
#  'MCStat_2023preBPix_RECO_NJ_1p0_2p0_cat2',
#  'MCStat_2023preBPix_RECO_NJ_2p0_3p0_cat0',
#  'MCStat_2023preBPix_RECO_NJ_2p0_3p0_cat1',
#  'MCStat_2023preBPix_RECO_NJ_2p0_3p0_cat2',
#  'MCStat_2023preBPix_RECO_NJ_3p0_4p0_cat0',
#  'MCStat_2023preBPix_RECO_NJ_3p0_4p0_cat1',
#  'MCStat_2023preBPix_RECO_NJ_3p0_4p0_cat2',
#  'MCStat_2023preBPix_RECO_NJ_4p0_100p0_cat0',
#  'MCStat_2023preBPix_RECO_NJ_4p0_100p0_cat1',
#  'MCStat_2023preBPix_RECO_NJ_4p0_100p0_cat2',
#  'MCStat_2023preBPix_RECO_PTH_0p0_5p0_cat0',
#  'MCStat_2023preBPix_RECO_PTH_0p0_5p0_cat1',
#  'MCStat_2023preBPix_RECO_PTH_0p0_5p0_cat2',
#  'MCStat_2023preBPix_RECO_PTH_100p0_120p0_cat0',
#  'MCStat_2023preBPix_RECO_PTH_100p0_120p0_cat1',
#  'MCStat_2023preBPix_RECO_PTH_100p0_120p0_cat2',
#  'MCStat_2023preBPix_RECO_PTH_10p0_15p0_cat0',
#  'MCStat_2023preBPix_RECO_PTH_10p0_15p0_cat1',
#  'MCStat_2023preBPix_RECO_PTH_10p0_15p0_cat2',
#  'MCStat_2023preBPix_RECO_PTH_120p0_140p0_cat0',
#  'MCStat_2023preBPix_RECO_PTH_120p0_140p0_cat1',
#  'MCStat_2023preBPix_RECO_PTH_120p0_140p0_cat2',
#  'MCStat_2023preBPix_RECO_PTH_140p0_170p0_cat0',
#  'MCStat_2023preBPix_RECO_PTH_140p0_170p0_cat1',
#  'MCStat_2023preBPix_RECO_PTH_140p0_170p0_cat2',
#  'MCStat_2023preBPix_RECO_PTH_15p0_20p0_cat0',
#  'MCStat_2023preBPix_RECO_PTH_15p0_20p0_cat1',
#  'MCStat_2023preBPix_RECO_PTH_15p0_20p0_cat2',
#  'MCStat_2023preBPix_RECO_PTH_170p0_200p0_cat0',
#  'MCStat_2023preBPix_RECO_PTH_170p0_200p0_cat1',
#  'MCStat_2023preBPix_RECO_PTH_170p0_200p0_cat2',
#  'MCStat_2023preBPix_RECO_PTH_200p0_250p0_cat0',
#  'MCStat_2023preBPix_RECO_PTH_200p0_250p0_cat1',
#  'MCStat_2023preBPix_RECO_PTH_200p0_250p0_cat2',
#  'MCStat_2023preBPix_RECO_PTH_20p0_25p0_cat0',
#  'MCStat_2023preBPix_RECO_PTH_20p0_25p0_cat1',
#  'MCStat_2023preBPix_RECO_PTH_20p0_25p0_cat2',
#  'MCStat_2023preBPix_RECO_PTH_250p0_350p0_cat0',
#  'MCStat_2023preBPix_RECO_PTH_250p0_350p0_cat1',
#  'MCStat_2023preBPix_RECO_PTH_250p0_350p0_cat2',
#  'MCStat_2023preBPix_RECO_PTH_25p0_30p0_cat0',
#  'MCStat_2023preBPix_RECO_PTH_25p0_30p0_cat1',
#  'MCStat_2023preBPix_RECO_PTH_25p0_30p0_cat2',
#  'MCStat_2023preBPix_RECO_PTH_30p0_35p0_cat0',
#  'MCStat_2023preBPix_RECO_PTH_30p0_35p0_cat1',
#  'MCStat_2023preBPix_RECO_PTH_30p0_35p0_cat2',
#  'MCStat_2023preBPix_RECO_PTH_350p0_450p0_cat0',
#  'MCStat_2023preBPix_RECO_PTH_350p0_450p0_cat1',
#  'MCStat_2023preBPix_RECO_PTH_350p0_450p0_cat2',
#  'MCStat_2023preBPix_RECO_PTH_35p0_45p0_cat0',
#  'MCStat_2023preBPix_RECO_PTH_35p0_45p0_cat1',
#  'MCStat_2023preBPix_RECO_PTH_35p0_45p0_cat2',
#  'MCStat_2023preBPix_RECO_PTH_450p0_10000p0_catMerged',
#  'MCStat_2023preBPix_RECO_PTH_45p0_60p0_cat0',
#  'MCStat_2023preBPix_RECO_PTH_45p0_60p0_cat1',
#  'MCStat_2023preBPix_RECO_PTH_45p0_60p0_cat2',
#  'MCStat_2023preBPix_RECO_PTH_5p0_10p0_cat0',
#  'MCStat_2023preBPix_RECO_PTH_5p0_10p0_cat1',
#  'MCStat_2023preBPix_RECO_PTH_5p0_10p0_cat2',
#  'MCStat_2023preBPix_RECO_PTH_60p0_80p0_cat0',
#  'MCStat_2023preBPix_RECO_PTH_60p0_80p0_cat1',
#  'MCStat_2023preBPix_RECO_PTH_60p0_80p0_cat2',
#  'MCStat_2023preBPix_RECO_PTH_80p0_100p0_cat0',
#  'MCStat_2023preBPix_RECO_PTH_80p0_100p0_cat1',
#  'MCStat_2023preBPix_RECO_PTH_80p0_100p0_cat2',
#  'MCStat_2023preBPix_RECO_PTJ0_120p0_150p0_cat0',
#  'MCStat_2023preBPix_RECO_PTJ0_120p0_150p0_cat1',
#  'MCStat_2023preBPix_RECO_PTJ0_120p0_150p0_cat2',
#  'MCStat_2023preBPix_RECO_PTJ0_150p0_200p0_cat0',
#  'MCStat_2023preBPix_RECO_PTJ0_150p0_200p0_cat1',
#  'MCStat_2023preBPix_RECO_PTJ0_150p0_200p0_cat2',
#  'MCStat_2023preBPix_RECO_PTJ0_200p0_10000p0_cat0',
#  'MCStat_2023preBPix_RECO_PTJ0_200p0_10000p0_cat1',
#  'MCStat_2023preBPix_RECO_PTJ0_200p0_10000p0_cat2',
#  'MCStat_2023preBPix_RECO_PTJ0_30p0_40p0_cat0',
#  'MCStat_2023preBPix_RECO_PTJ0_30p0_40p0_cat1',
#  'MCStat_2023preBPix_RECO_PTJ0_30p0_40p0_cat2',
#  'MCStat_2023preBPix_RECO_PTJ0_40p0_55p0_cat0',
#  'MCStat_2023preBPix_RECO_PTJ0_40p0_55p0_cat1',
#  'MCStat_2023preBPix_RECO_PTJ0_40p0_55p0_cat2',
#  'MCStat_2023preBPix_RECO_PTJ0_55p0_75p0_cat0',
#  'MCStat_2023preBPix_RECO_PTJ0_55p0_75p0_cat1',
#  'MCStat_2023preBPix_RECO_PTJ0_55p0_75p0_cat2',
#  'MCStat_2023preBPix_RECO_PTJ0_75p0_95p0_cat0',
#  'MCStat_2023preBPix_RECO_PTJ0_75p0_95p0_cat1',
#  'MCStat_2023preBPix_RECO_PTJ0_75p0_95p0_cat2',
#  'MCStat_2023preBPix_RECO_PTJ0_95p0_120p0_cat0',
#  'MCStat_2023preBPix_RECO_PTJ0_95p0_120p0_cat1',
#  'MCStat_2023preBPix_RECO_PTJ0_95p0_120p0_cat2',
#  'MCStat_2023preBPix_RECO_PTJ0_m10000p0_30p0_cat0',
#  'MCStat_2023preBPix_RECO_PTJ0_m10000p0_30p0_cat1',
#  'MCStat_2023preBPix_RECO_PTJ0_m10000p0_30p0_cat2',
#  'MCStat_2024_RECO_NJ_0p0_1p0_cat0',
#  'MCStat_2024_RECO_NJ_0p0_1p0_cat1',
#  'MCStat_2024_RECO_NJ_0p0_1p0_cat2',
#  'MCStat_2024_RECO_NJ_1p0_2p0_cat0',
#  'MCStat_2024_RECO_NJ_1p0_2p0_cat1',
#  'MCStat_2024_RECO_NJ_1p0_2p0_cat2',
#  'MCStat_2024_RECO_NJ_2p0_3p0_cat0',
#  'MCStat_2024_RECO_NJ_2p0_3p0_cat1',
#  'MCStat_2024_RECO_NJ_2p0_3p0_cat2',
#  'MCStat_2024_RECO_NJ_3p0_4p0_cat0',
#  'MCStat_2024_RECO_NJ_3p0_4p0_cat1',
#  'MCStat_2024_RECO_NJ_3p0_4p0_cat2',
#  'MCStat_2024_RECO_NJ_4p0_100p0_cat0',
#  'MCStat_2024_RECO_NJ_4p0_100p0_cat1',
#  'MCStat_2024_RECO_NJ_4p0_100p0_cat2',
#  'MCStat_2024_RECO_PTH_0p0_5p0_cat0',
#  'MCStat_2024_RECO_PTH_0p0_5p0_cat1',
#  'MCStat_2024_RECO_PTH_0p0_5p0_cat2',
#  'MCStat_2024_RECO_PTH_100p0_120p0_cat0',
#  'MCStat_2024_RECO_PTH_100p0_120p0_cat1',
#  'MCStat_2024_RECO_PTH_100p0_120p0_cat2',
#  'MCStat_2024_RECO_PTH_10p0_15p0_cat0',
#  'MCStat_2024_RECO_PTH_10p0_15p0_cat1',
#  'MCStat_2024_RECO_PTH_10p0_15p0_cat2',
#  'MCStat_2024_RECO_PTH_120p0_140p0_cat0',
#  'MCStat_2024_RECO_PTH_120p0_140p0_cat1',
#  'MCStat_2024_RECO_PTH_120p0_140p0_cat2',
#  'MCStat_2024_RECO_PTH_140p0_170p0_cat0',
#  'MCStat_2024_RECO_PTH_140p0_170p0_cat1',
#  'MCStat_2024_RECO_PTH_140p0_170p0_cat2',
#  'MCStat_2024_RECO_PTH_15p0_20p0_cat0',
#  'MCStat_2024_RECO_PTH_15p0_20p0_cat1',
#  'MCStat_2024_RECO_PTH_15p0_20p0_cat2',
#  'MCStat_2024_RECO_PTH_170p0_200p0_cat0',
#  'MCStat_2024_RECO_PTH_170p0_200p0_cat1',
#  'MCStat_2024_RECO_PTH_170p0_200p0_cat2',
#  'MCStat_2024_RECO_PTH_200p0_250p0_cat0',
#  'MCStat_2024_RECO_PTH_200p0_250p0_cat1',
#  'MCStat_2024_RECO_PTH_200p0_250p0_cat2',
#  'MCStat_2024_RECO_PTH_20p0_25p0_cat0',
#  'MCStat_2024_RECO_PTH_20p0_25p0_cat1',
#  'MCStat_2024_RECO_PTH_20p0_25p0_cat2',
#  'MCStat_2024_RECO_PTH_250p0_350p0_cat0',
#  'MCStat_2024_RECO_PTH_250p0_350p0_cat1',
#  'MCStat_2024_RECO_PTH_250p0_350p0_cat2',
#  'MCStat_2024_RECO_PTH_25p0_30p0_cat0',
#  'MCStat_2024_RECO_PTH_25p0_30p0_cat1',
#  'MCStat_2024_RECO_PTH_25p0_30p0_cat2',
#  'MCStat_2024_RECO_PTH_30p0_35p0_cat0',
#  'MCStat_2024_RECO_PTH_30p0_35p0_cat1',
#  'MCStat_2024_RECO_PTH_30p0_35p0_cat2',
#  'MCStat_2024_RECO_PTH_350p0_450p0_cat0',
#  'MCStat_2024_RECO_PTH_350p0_450p0_cat1',
#  'MCStat_2024_RECO_PTH_350p0_450p0_cat2',
#  'MCStat_2024_RECO_PTH_35p0_45p0_cat0',
#  'MCStat_2024_RECO_PTH_35p0_45p0_cat1',
#  'MCStat_2024_RECO_PTH_35p0_45p0_cat2',
#  'MCStat_2024_RECO_PTH_450p0_10000p0_cat0',
#  'MCStat_2024_RECO_PTH_450p0_10000p0_cat1',
#  'MCStat_2024_RECO_PTH_450p0_10000p0_cat2',
#  'MCStat_2024_RECO_PTH_45p0_60p0_cat0',
#  'MCStat_2024_RECO_PTH_45p0_60p0_cat1',
#  'MCStat_2024_RECO_PTH_45p0_60p0_cat2',
#  'MCStat_2024_RECO_PTH_5p0_10p0_cat0',
#  'MCStat_2024_RECO_PTH_5p0_10p0_cat1',
#  'MCStat_2024_RECO_PTH_5p0_10p0_cat2',
#  'MCStat_2024_RECO_PTH_60p0_80p0_cat0',
#  'MCStat_2024_RECO_PTH_60p0_80p0_cat1',
#  'MCStat_2024_RECO_PTH_60p0_80p0_cat2',
#  'MCStat_2024_RECO_PTH_80p0_100p0_cat0',
#  'MCStat_2024_RECO_PTH_80p0_100p0_cat1',
#  'MCStat_2024_RECO_PTH_80p0_100p0_cat2',
#  'MCStat_2024_RECO_PTJ0_120p0_150p0_cat0',
#  'MCStat_2024_RECO_PTJ0_120p0_150p0_cat1',
#  'MCStat_2024_RECO_PTJ0_120p0_150p0_cat2',
#  'MCStat_2024_RECO_PTJ0_150p0_200p0_cat0',
#  'MCStat_2024_RECO_PTJ0_150p0_200p0_cat1',
#  'MCStat_2024_RECO_PTJ0_150p0_200p0_cat2',
#  'MCStat_2024_RECO_PTJ0_200p0_10000p0_cat0',
#  'MCStat_2024_RECO_PTJ0_200p0_10000p0_cat1',
#  'MCStat_2024_RECO_PTJ0_200p0_10000p0_cat2',
#  'MCStat_2024_RECO_PTJ0_30p0_40p0_cat0',
#  'MCStat_2024_RECO_PTJ0_30p0_40p0_cat1',
#  'MCStat_2024_RECO_PTJ0_30p0_40p0_cat2',
#  'MCStat_2024_RECO_PTJ0_40p0_55p0_cat0',
#  'MCStat_2024_RECO_PTJ0_40p0_55p0_cat1',
#  'MCStat_2024_RECO_PTJ0_40p0_55p0_cat2',
#  'MCStat_2024_RECO_PTJ0_55p0_75p0_cat0',
#  'MCStat_2024_RECO_PTJ0_55p0_75p0_cat1',
#  'MCStat_2024_RECO_PTJ0_55p0_75p0_cat2',
#  'MCStat_2024_RECO_PTJ0_75p0_95p0_cat0',
#  'MCStat_2024_RECO_PTJ0_75p0_95p0_cat1',
#  'MCStat_2024_RECO_PTJ0_75p0_95p0_cat2',
#  'MCStat_2024_RECO_PTJ0_95p0_120p0_cat0',
#  'MCStat_2024_RECO_PTJ0_95p0_120p0_cat1',
#  'MCStat_2024_RECO_PTJ0_95p0_120p0_cat2',
#  'MCStat_2024_RECO_PTJ0_m10000p0_30p0_cat0',
#  'MCStat_2024_RECO_PTJ0_m10000p0_30p0_cat1',
#  'MCStat_2024_RECO_PTJ0_m10000p0_30p0_cat2',
#  'lumi_1',
#  'lumi_2',
#  'lumi_3']

# %%
import json


pois = {
    "PTH": ["r_PTH_0p0_5p0","r_PTH_5p0_10p0","r_PTH_10p0_15p0","r_PTH_15p0_20p0","r_PTH_20p0_25p0","r_PTH_25p0_30p0","r_PTH_30p0_35p0","r_PTH_35p0_45p0","r_PTH_45p0_60p0","r_PTH_60p0_80p0","r_PTH_80p0_100p0","r_PTH_100p0_120p0","r_PTH_120p0_140p0","r_PTH_140p0_170p0","r_PTH_170p0_200p0","r_PTH_200p0_250p0","r_PTH_250p0_350p0","r_PTH_350p0_450p0","r_PTH_450p0_10000p0"],
    "NJ": ["r_NJ_0p0_1p0", "r_NJ_1p0_2p0", "r_NJ_2p0_3p0", "r_NJ_3p0_4p0", "r_NJ_4p0_100p0"],
    "PTJ0": ["r_PTJ0_m10000p0_30p0", "r_PTJ0_30p0_40p0", "r_PTJ0_40p0_55p0", "r_PTJ0_55p0_75p0", "r_PTJ0_75p0_95p0", "r_PTJ0_95p0_120p0", "r_PTJ0_120p0_150p0", "r_PTJ0_150p0_200p0", "r_PTJ0_200p0_10000p0"],
    # "YH": ["r_YH_0p0_0p15", "r_YH_0p15_0p3", "r_YH_0p3_0p45", "r_YH_0p45_0p6", "r_YH_0p6_0p75", "r_YH_0p75_0p9", "r_YH_0p9_1p2", "r_YH_1p2_1p6", "r_YH_1p6_2p0", "r_YH_2p0_2p5"]
}

# %%
idx_ptJ0 = {p["name"]: p for p in impacts_ptJ0["params"]}
idx_PTH  = {p["name"]: p for p in impacts_PTH["params"]}
idx_NJ   = {p["name"]: p for p in impacts_NJ["params"]}
idx_YH   = {p["name"]: p for p in impacts_YH["params"]}

def variation(v):
    v0, v1, v2 = map(float, v)
    d1 = v2 - v1   # +1σ
    d2 = v0 - v1   # -1σ
    return np.sign(d1) * max(abs(d1), abs(d2))
    # return (d1 - d2) / 2
    # return d1

def block_vector(entry, pois):
    if entry is None:
        return [0.0] * len(pois)
    return [variation(entry[poi]) if poi in entry else 0.0 for poi in pois]

nuis_to_vector = {}
for n in nuis_params:  # full list you provide
    e_PTH  = idx_PTH.get(n)     # None if missing
    e_NJ   = idx_NJ.get(n)
    e_ptJ0 = idx_ptJ0.get(n)
    e_YH = idx_YH.get(n)
    vec = (
        block_vector(e_PTH,  pois["PTH"]) +
        block_vector(e_NJ,   pois["NJ"]) +
        block_vector(e_ptJ0, pois["PTJ0"])# +
        # block_vector(e_YH, pois["YH"])
    )
    nuis_to_vector[n] = np.array(vec, dtype=float).reshape(-1, 1)  # vertical

# %%
## After this cell you have syst_matrix and syst_matrix_reduced
# n_entries = len(pois["PTJ0"]) + len(pois["PTH"]) + len(pois["NJ"]) + len(pois["YH"])
n_entries = len(pois["PTH"]) + len(pois["NJ"]) + len(pois["PTJ0"])
syst_matrix = np.zeros((n_entries, n_entries))
for nuis in nuis_params:
# for nuis in ["CMS_scale_j_2022postEE", "CMS_scale_j_2022preEE"]:
    syst_matrix += nuis_to_vector[nuis] @ nuis_to_vector[nuis].T

syst_matrix = pd.DataFrame(syst_matrix, index=cov["cat2"].index, columns=cov["cat2"].columns)
label_to_drop = syst_matrix.index[12]
syst_matrix_red = pd.DataFrame(syst_matrix.drop(index=label_to_drop, columns=label_to_drop))
syst_matrix_red.index = cor_cholesky_red.index
syst_matrix_red.columns = cor_cholesky_red.index

# %%
def find_crossings(x_vals, y_vals, threshold=1.0):
    # Find where the difference changes sign
    y_vals = np.array(y_vals)  # ← add this line
    signs = np.sign(y_vals - threshold)
    crossings = []
    for i in range(len(signs)-1):
        if signs[i] * signs[i+1] <= 0:  # Sign change detected
            # Linear interpolation
            x1, x2 = x_vals[i], x_vals[i+1]
            y1, y2 = y_vals[i], y_vals[i+1]
            if y1 != y2:  # Avoid division by zero
                x_cross = x1 + (x2-x1) * (threshold-y1)/(y2-y1)
                crossings.append(x_cross)
    return crossings

# %%
# I wanna derive the uncertainties based off the fidXS calculator and the scans

TARGET_MODES = {"ggH", "VBFH", "VH", "ttH"}

FILE_RE = re.compile(
    # r"^fidXS_(?P<obs>NJ|PTH|PTJ0|YH)_(?P<mode>ggH|VBFH|VH|ttH)\.py$"
    r"^fidXS_(?P<obs>PTH|NJ|PTJ0)_(?P<mode>ggH|VBFH|VH|ttH)\.py$"
)

def load_python_module(path: Path):
    spec = importlib.util.spec_from_file_location(path.stem, path)
    if spec is None or spec.loader is None:
        raise RuntimeError(f"Cannot load file: {path}")
    module = importlib.util.module_from_spec(spec)
    spec.loader.exec_module(module)
    return module

unc_total = {
    "PTH": [],
    "NJ": [],
    "PTJ0": [],
    # "YH": []
}

fidXS_sum = {
    "PTH": None,
    "NJ": None,
    "PTJ0": None,
    # "YH": None
}

fidXS_folder = Path("fidXS")

for path in fidXS_folder.iterdir():
    match = FILE_RE.match(path.name)
    if not match:
        continue

    obs = match.group("obs")
    mode = match.group("mode")

    if mode not in TARGET_MODES:
        continue

    module = load_python_module(path)

    if not hasattr(module, "fidXS"):
        print(f"Skipping {path.name}: no fidXS vector")
        continue

    fid_xs = np.array(list(module.fidXS))  # convert once to numpy

    # initialize accumulator
    if fidXS_sum[obs] is None:
        fidXS_sum[obs] = fid_xs.copy()
    else:
        # safety check: bin consistency
        if fidXS_sum[obs].shape != fid_xs.shape:
            raise ValueError(
                f"Bin mismatch in {path.name}: "
                f"{fidXS_sum[obs].shape} vs {fid_xs.shape}"
            )

        fidXS_sum[obs] += fid_xs

# Load the scans and extract the 1 sigmas
blinded = True

if blinded:
    scan_folder = {
        "PTH": "/pnfs/psi.ch/cms/trivcat/store/user/niharrin/ntuples/midRun3/samples/2026_04_27_with_Zmmg_SaS/final_fits_outputs/PTH/Combine/runFits_PTH/asimov/scans",
        "NJ": "/pnfs/psi.ch/cms/trivcat/store/user/niharrin/ntuples/midRun3/samples/2026_04_27_with_Zmmg_SaS/final_fits_outputs/NJ/Combine/runFits_NJ/asimov/scans",
        "PTJ0": "/pnfs/psi.ch/cms/trivcat/store/user/niharrin/ntuples/midRun3/samples/2026_04_27_with_Zmmg_SaS/final_fits_outputs/PTJ0/Combine/runFits_PTJ0/asimov/scans",
        # "YH": "/pnfs/psi.ch/cms/trivcat/store/user/niharrin/ntuples/midRun3/samples/2026_04_27_with_Zmmg_SaS/final_fits_outputs/YH/Combine/runFits_YH/asimov/scans"
    }
else:
    scan_folder = {
        "PTH": "/pnfs/psi.ch/cms/trivcat/store/user/niharrin/ntuples/midRun3/samples/2026_04_27_with_Zmmg_SaS/final_fits_outputs/PTH/Combine/runFits_PTH/data/scans",
        "NJ": "/pnfs/psi.ch/cms/trivcat/store/user/niharrin/ntuples/midRun3/samples/2026_04_27_with_Zmmg_SaS/final_fits_outputs/NJ/Combine/runFits_NJ/data/scans",
        "PTJ0": "/pnfs/psi.ch/cms/trivcat/store/user/niharrin/ntuples/midRun3/samples/2026_04_27_with_Zmmg_SaS/final_fits_outputs/PTJ0/Combine/runFits_PTJ0/data/scans",
        # "YH": "/pnfs/psi.ch/cms/trivcat/store/user/niharrin/ntuples/midRun3/samples/2026_04_27_with_Zmmg_SaS/final_fits_outputs/YH/Combine/runFits_YH/data/scans"
    }



for poi in pois.keys():

    for i, current_bin in enumerate(pois[poi]):
        try:
            with uproot.open(os.path.join(scan_folder[poi].replace("YH", "rapidity"), f"scan_{current_bin}.root")) as file:
                
                # Get the TGraphs - note that uproot reads them as pairs of arrays
                graph = file[f"scan_{current_bin};1"]  # Replace with your TGraph name
                # Extract x and y values
                x0_points = graph.member("fX")  # Gets x values
                y0_points = graph.member("fY")  # Gets y values
        except:
            print(f"Error: Could not load scan for {current_bin} from {scan_folder[poi]}. Perhaps run unblinded scans first. Skipping this bin.")
            continue

        mu_hat = x0_points[np.argmin(y0_points)] # Consider an Asimov dataset
        # print("XS crossings", find_crossings(x0_points, y0_points))
        if len(find_crossings(x0_points, y0_points)) != 2:
            print(f"Warning: Expected two crossings for {current_bin}, found {len(find_crossings(x0_points, y0_points))}.")
            if len(find_crossings(x0_points, y0_points)) == 1:
                print("Only one crossing found. Assuming symmetric shape and extracting only the one point.")
                crossing = find_crossings(x0_points, y0_points)[0]
            else:
                crossing_minus, crossing_plus = find_crossings(x0_points, y0_points)[-2:]  # Use the last two crossings
        else:
            crossing_minus, crossing_plus = find_crossings(x0_points, y0_points)
        
        if len(find_crossings(x0_points, y0_points)) == 1:
            sigma_minus = mu_hat - crossing
            sigma_plus = crossing - mu_hat
        else:
            sigma_minus = mu_hat - crossing_minus
            sigma_plus = crossing_plus - mu_hat
            
        fidXS_low = fidXS_sum[poi][i] * sigma_minus
        fidXS_high = fidXS_sum[poi][i] * sigma_plus
        
        unc_total[poi].append(fidXS_high)


fidXS_PTH = [3.251514094855517, 6.413825763609831, 6.555809968521467, 5.889800810939074, 5.099083112515962, 4.421885114513488, 3.866226543790849, 6.441680337807897, 6.902988952146682, 5.9025422289283505, 3.8146832368240626, 2.5035992765212907, 1.728313772250199, 1.7476552427460155, 1.0831025476943583, 1.0182794676925542, 0.8199434493201138, 0.25644320024731754, 0.16456440773573974]
fidXS_NJ = [36.46013279924294, 19.39595337442149, 8.780897688557815, 2.1285339711776765, 1.117648241828872]
fidXS_PTJ0 = [36.46013279924294, 6.663873021305533, 7.050146523728949, 5.894645706317997, 3.654783295750552, 2.8293975792219843, 1.990389506704825, 1.6537018867095121, 38.14622855548648]
fidXS_YH = [6.571010820445315, 6.4878499407752805, 6.374530083157725, 6.159720064093899, 5.79610179997262, 5.471530119936904, 9.913956621106973, 10.81253639411838, 7.0842765398757725, 3.211653691747486]

# We always take the bigger ones to be more conservative
uncMu_total_PTH = [0.481, 0.339, 0.355, 0.365, 0.410, 0.446, 0.457, 0.300, 0.258, 0.249, 0.260, 0.284, 0.305, 0.251, 0.287, 0.259, 0.259, 0.429, 0.582]
uncMu_stat_PTH = [0.480, 0.337, 0.354, 0.364, 0.406, 0.442, 0.455, 0.298, 0.256, 0.247, 0.258, 0.283, 0.304, 0.250, 0.285, 0.258, 0.258, 0.427, 0.580]
unc_total_PTH = [uncMu_total_PTH[i]*currentXS for i, currentXS in enumerate(fidXS_PTH)]
unc_stat_PTH = [uncMu_stat_PTH[i]*currentXS for i, currentXS in enumerate(fidXS_PTH)]
unc_syst_PTH = [np.sqrt(unc_total_PTH[i]**2 - unc_stat_PTH[i]**2) for i, _ in enumerate(unc_total_PTH)]

uncMu_total_NJ = [0.150, 0.223, 0.315, 0.672, 0.619]
uncMu_stat_NJ = [0.145, 0.220, 0.311, 0.665, 0.614]
unc_total_NJ = [uncMu_total_NJ[i]*currentXS for i, currentXS in enumerate(fidXS_NJ)]
unc_stat_NJ = [uncMu_stat_NJ[i]*currentXS for i, currentXS in enumerate(fidXS_NJ)]
unc_syst_NJ = [np.sqrt(unc_total_NJ[i]**2 - unc_stat_NJ[i]**2) for i, _ in enumerate(unc_total_NJ)]

uncMu_total_PTJ0 = [0.163, 0.958, 0.841, 0.751, 0.964, 0.927, 0.854, 0.594, 0.349]
uncMu_stat_PTJ0 = [0.155, 0.954, 0.836, 0.747, 0.960, 0.922, 0.851, 0.591, 0.346]
unc_total_PTJ0 = [uncMu_total_PTJ0[i]*currentXS for i, currentXS in enumerate(fidXS_PTJ0)]
unc_stat_PTJ0 = [uncMu_stat_PTJ0[i]*currentXS for i, currentXS in enumerate(fidXS_PTJ0)]
unc_syst_PTJ0 = [np.sqrt(unc_total_PTJ0[i]**2 - unc_stat_PTJ0[i]**2) for i, _ in enumerate(unc_total_PTJ0)]

uncMu_total_YH = [0.190, 0.202, 0.211, 0.227, 0.253, 0.273, 0.236, 0.305, 0.422, 0.709]
uncMu_stat_YH = [0.188, 0.201, 0.210, 0.226, 0.252, 0.271, 0.234, 0.303, 0.422, 0.706]
unc_total_YH = [uncMu_total_YH[i]*currentXS for i, currentXS in enumerate(fidXS_YH)]
unc_stat_YH = [uncMu_stat_YH[i]*currentXS for i, currentXS in enumerate(fidXS_YH)]
unc_syst_YH = [np.sqrt(unc_total_YH[i]**2 - unc_stat_YH[i]**2) for i, _ in enumerate(unc_total_YH)]

## These are the uncertainties taken from HIG-23-014
# unc_stat_PTH = [0.57562, 0.49025, 0.33738,  0.16279,  0.073269, 0.018874,  0.0033147,  0.0006698] 
# unc_syst_PTH = [0.12178, 0.11362, 0.076966, 0.022287, 0.01272,  0.0059666, 0.00049481, 7.4847e-05]

# unc_stat_NJ = [11.156, 6.8513, 3.7298, 1.8594]
# unc_syst_NJ = [5.2144, 1.3159, 0.7901, 0.34139]

# unc_stat_ptJ0 = [0.010956, 0.16787, 0.081892, 0.023149, 0.00087127]
# unc_syst_ptJ0 = [0.0049906, 0.021763, 0.015088, 0.004048, 0.000085128]
## without the underflow bin
# unc_stat_ptJ0 = [0.16787, 0.081892, 0.023149, 0.00087127]
# unc_syst_ptJ0 = [0.021763, 0.015088, 0.004048, 0.000085128]

# # Mangels Geduld... (to be changed)
# unc_stat_syst = unc_total["PTH"] #+ unc_total["NJ"]# + unc_total["PTJ0"] #+ unc_total["YH"]

unc_stat = unc_stat_PTH + unc_stat_NJ + unc_stat_PTJ0 
unc_syst = unc_syst_PTH + unc_syst_NJ + unc_syst_PTJ0

# %%
cov_stat = cor_cholesky * np.outer(unc_stat, unc_stat)
cov_syst = syst_matrix * np.outer(unc_syst, unc_syst)

# cov_stat = cor_cholesky * np.outer(unc_stat_syst, unc_stat_syst)
# cov_syst = syst_matrix * np.outer(unc_stat_syst, unc_stat_syst)
cov_tot = cov_stat + cov_syst
corr_tot = corr_from_cov(cov_tot)
plot_corr(corr_tot, title="Total correlation matrix (stat + syst)", save_path="correlation_matrix_total_reduced.pdf", label_map=label_map)

# %%
plot_cov(cov_syst, title="Systematic covariance matrix", save_path="covariance_matrix_systematic_reduced.pdf")

# %% [markdown]
# #### Theory covariance matrix

# %%
# first, load the variances for alpha s and PDF as discussed with AT

FILE_RE = re.compile(
    # r"^fidXS_(?P<obs>NJ|PTH|PTJ0|YH)_all\.py$"
    r"^fidXS_(?P<obs>PTH)_all\.py$"
)

def load_python_module(path: Path):
    spec = importlib.util.spec_from_file_location(path.stem, path)
    if spec is None or spec.loader is None:
        raise RuntimeError(f"Cannot load file: {path}")
    module = importlib.util.module_from_spec(spec)
    spec.loader.exec_module(module)
    return module

var = {
    "alpha": {
        "PTH": [],
        # "NJ": [],
        # "PTJ0": [],
        # "YH": []
    },
    "pdf": {
        "PTH": [],
        # "NJ": [],
        # "PTJ0": [],
        # "YH": []
    }
}

fidXS_folder = Path("fidXS")

for path in fidXS_folder.iterdir():
    match = FILE_RE.match(path.name)
    if not match:
        continue

    obs = match.group("obs")

    module = load_python_module(path)

    if not hasattr(module, "fidXS"):
        print(f"Skipping {path.name}: no fidXS vector")
        continue

    fid_xs_nom = np.array(list(module.fidXS))  # convert once to numpy
    fid_xs_pdf_up = np.array(list(module.fidXS_pdf_up))
    fid_xs_alpha_up = np.array(list(module.fidXS_alpha_up))

    fid_xs_pdf_dn = np.array(list(module.fidXS_pdf_dn))
    fid_xs_alpha_dn = np.array(list(module.fidXS_alpha_dn))
  
    for i, nom_xs in enumerate(fid_xs_nom):
        var["alpha"][obs].append(fid_xs_alpha_up[i] - fid_xs_nom[i])
        var["pdf"][obs].append(fid_xs_pdf_up[i] - fid_xs_nom[i])

# %%
# We fully correlate the Alpha S and PDF uncertainties

# Build the correlation matrix
n_bins = len(var["alpha"]["PTH"])# + len(var["alpha"]["NJ"]) + len(var["alpha"]["PTJ0"]) #+ len(var["alpha"]["YH"])
matrix = np.ones((n_bins, n_bins), dtype=int)

# Use the dictionary values (or keys) as labels
labels = list(label_map.values())

correlation = pd.DataFrame(
    matrix,
    index=labels,
    columns=labels
)

# %%
# Build the global ordered list of bins
all_bins = []
for obs in pois:
    all_bins.extend(pois[obs])

# Replace the nested dicts with column-vector DataFrames
for source in var:

    values = []

    for obs in pois:
        values.extend(var[source][obs])

    var[source] = pd.DataFrame(
        values,
        index=all_bins,
        columns=[source]
    )

# %%
# Now compute the covariance per source

v_pdf = var["pdf"].iloc[:, 0]
Cov_pdf = correlation.mul(v_pdf, axis=0).mul(v_pdf, axis=1)

v_alpha = var["alpha"].iloc[:, 0]
Cov_alpha = correlation.mul(v_alpha, axis=0).mul(v_alpha, axis=1)

# %%
FILE_RE = re.compile(
    # r"^fidXS_(?P<obs>PTH|NJ|PTJ0|YH)_all_(?P<scale>0|1|3|5|7|8)\.py$"
    r"^fidXS_(?P<obs>PTH)_all_scale(?P<scale>0|1|3|5|7|8)\.py$"
)

def load_python_module(path: Path):
    spec = importlib.util.spec_from_file_location(path.stem, path)
    if spec is None or spec.loader is None:
        raise RuntimeError(f"Cannot load file: {path}")
    module = importlib.util.module_from_spec(spec)
    spec.loader.exec_module(module)
    return module

scale_variations = {
    "0": {
        "PTH": [],
        # "NJ": [],
        # "PTJ0": [],
        # "YH": [],
    },
    "1": {
        "PTH": [],
        # "NJ": [],
        # "PTJ0": [],
        # "YH": [],
    },
    "3": {
        "PTH": [],
        # "NJ": [],
        # "PTJ0": [],
        # "YH": [],
    },
    "5": {
        "PTH": [],
        # "NJ": [],
        # "PTJ0": [],
        # "YH": [],
    },
    "7": {
        "PTH": [],
        # "NJ": [],
        # "PTJ0": [],
        # "YH": [],
    },
    "8": {
        "PTH": [],
        # "NJ": [],
        # "PTJ0": [],
        # "YH": [],
    }
}

fidXS_folder = Path("fidXS")

for path in fidXS_folder.iterdir():
    match = FILE_RE.match(path.name)
    if not match:
        continue

    obs = match.group("obs")
    scale = match.group("scale")

    module = load_python_module(path)

    if not hasattr(module, "fidXS"):
        print(f"Skipping {path.name}: no fidXS vector")
        continue

    sigma = np.array(list(module.fidXS))  # convert once to numpy
    up = np.array(list(module.fidXS_scale_up))
    
    scale_variations[scale][obs] = up - sigma

# %%
# observables = ["PTH", "NJ", "PTJ0", "YH"]
observables = ["PTH"]
bin_info = {
    "PTH": 19,
    # "NJ": 5,
    # "PTJ0": 9,
    # "YH": 10
}

# # -----------------------------
# # 1. Build column labels
# # -----------------------------
# cols = []
# for obs in observables:
#     for b in range(bin_info[obs]):
#         cols.append(f"{obs}_bin{b}")

# # -----------------------------
# # 2. Build data frame
# # -----------------------------
# data = []

# for i in scale_variations:
#     row = []
#     for obs in observables:
#         for b in range(bin_info[obs]):
#             row.append(scale_variations[i][obs][b])
#     data.append(row)

# df = pd.DataFrame(data, columns=cols)

# # -----------------------------
# # 3. Mean subtraction (important!)
# # -----------------------------
# df_centered = df - df.mean()

# df_centered= df_centered.rename(index=label_map_theory, columns=label_map_theory)

# # -----------------------------
# # 4. Covariance matrix
# # -----------------------------
# Cov_scale = df_centered.cov(ddof=0)   # same as bias=True in numpy

# # -----------------------------
# # 5. Correlation matrix
# # -----------------------------
# corr_scale = df_centered.corr()

# -----------------------------
# Build DataFrame (your setup)
# -----------------------------
cols = []
for obs in observables:
    for b in range(bin_info[obs]):
        cols.append(f"{obs}_bin{b}")

data = []

for i in scale_variations:
    row = []
    for obs in observables:
        for b in range(bin_info[obs]):
            row.append(scale_variations[i][obs][b])
    data.append(row)

df = pd.DataFrame(data, columns=cols)

# -----------------------------
# Cosine similarity matrix (UNCHANGED, uncentered)
# -----------------------------
bins = df.columns
n_bins = len(bins)

corr = pd.DataFrame(
    np.zeros((n_bins, n_bins)),
    index=bins,
    columns=bins
)

for a in bins:
    xa = df[a].to_numpy()

    denom_a = np.sum(xa ** 2)

    for b in bins:
        xb = df[b].to_numpy()

        denom_b = np.sum(xb ** 2)
        num = np.sum(xa * xb)

        corr.loc[a, b] = num / np.sqrt(denom_a * denom_b)

# %%
# Now compute the scale uncertainties from the fidXS output

FILE_RE = re.compile(
    r"^fidXS_(?P<obs>PTH)_all\.py$"
)

def load_python_module(path: Path):
    spec = importlib.util.spec_from_file_location(path.stem, path)
    if spec is None or spec.loader is None:
        raise RuntimeError(f"Cannot load file: {path}")
    module = importlib.util.module_from_spec(spec)
    spec.loader.exec_module(module)
    return module

scale_uncertainties = {
    "PTH": [],
    # "NJ": [],
    # "PTJ0": [],
    # "YH": [],
}

fidXS_folder = Path("fidXS")

for path in fidXS_folder.iterdir():
    match = FILE_RE.match(path.name)
    if not match:
        continue

    obs = match.group("obs")
    module = load_python_module(path)

    if not hasattr(module, "fidXS"):
        print(f"Skipping {path.name}: no fidXS vector")
        continue

    sigma = np.array(list(module.fidXS))  # convert once to numpy
    up = np.array(list(module.fidXS_scale_up))
    
    scale_uncertainties[obs] = up - sigma

unc = []

for obs in observables:
    unc.extend(scale_uncertainties[obs])  # your dict

sigma_THU = np.array(unc)

# %%
Cov_scale = corr * np.outer(sigma_THU, sigma_THU)

Cov_scale = pd.DataFrame(
    Cov_scale
)

Cov_scale = Cov_scale.rename(index=label_map_theory, columns=label_map_theory)

# %%
Cov_Theor = Cov_pdf + Cov_alpha + Cov_scale

# %%
cov_syst = cov_syst.rename(index=label_map, columns=label_map)
cov_stat = cov_stat.rename(index=label_map, columns=label_map)

cov_syst = cov_syst.loc[list(label_map.values()), list(label_map.values())]
cov_stat = cov_stat.loc[list(label_map.values()), list(label_map.values())]

# %%
cov_tot = cov_stat + cov_syst + Cov_Theor
corr_tot = corr_from_cov(cov_tot)

# %%
cov_tot = cov_tot.rename(index=label_map, columns=label_map)

# %%
corr_tot = corr_tot.loc[list(label_map.values()), list(label_map.values())]
cov_tot = cov_tot.loc[list(label_map.values()), list(label_map.values())]

# %%
plot_cov(cov_tot, title="Total covariance matrix", save_path="covariance_matrix_total_reduced.pdf")

# %%
plot_corr(corr_tot, title="Total correlation matrix", save_path="correlation_matrix_total_reduced.pdf")

# %% [markdown]
# #### Saving information in Nico-friendly format

# %%
## Save matrices in a Nico-friendly format
import yaml

def dataframe_to_yaml_rows(
    df,
    output_yaml,
    label_map,
    target_order=None,
    zero_tol=0.0,
):
    """
    Convert square DataFrame -> YAML list-of-row-dicts format.

    - df: pandas DataFrame (square)
    - output_yaml: output path
    - label_map: dict old_label -> new_label
    - target_order: list of NEW labels in desired final order.
                    If None, uses DataFrame order after renaming.
    - zero_tol: values with abs(x) < zero_tol are written as 0.0
    """
    if not isinstance(df, pd.DataFrame):
        raise TypeError("df must be a pandas DataFrame")
    if df.shape[0] != df.shape[1]:
        raise ValueError("df must be square")

    # Rename both axes
    m = df.rename(index=label_map, columns=label_map).copy()

    # If desired order not provided, keep current renamed order
    if target_order is None:
        target_order = list(m.index)

    # Validate target labels exist
    missing_rows = [x for x in target_order if x not in m.index]
    missing_cols = [x for x in target_order if x not in m.columns]
    if missing_rows or missing_cols:
        raise KeyError(
            f"Missing labels after renaming.\n"
            f"Rows missing: {missing_rows}\n"
            f"Cols missing: {missing_cols}"
        )

    # Reorder matrix
    m = m.loc[target_order, target_order].astype(float)

    # Build YAML structure: list of dicts (one row per item)
    rows = []
    for _, row in m.iterrows():
        d = {}
        for col, val in row.items():
            x = float(val)
            if abs(x) < zero_tol:
                x = 0.0
            d[col] = x
        rows.append(d)

    with open(output_yaml, "w") as f:
        yaml.safe_dump(rows, f, sort_keys=False, default_flow_style=False)

# %%
target_order = pois["PTH"] + pois["NJ"] + pois["PTJ0"]# + pois["YH"]

# %%
dataframe_to_yaml_rows(
    df=corr_tot, 
    output_yaml="corr_tot.yaml",
    label_map=label_map, 
    target_order=target_order,
    zero_tol=1e-12, ## zero_tol is the threshold below which numbers are forced to 0.0 when exporting
)

# %%
cov_tot
# Out:
#                       r_PTH_0p0_5p0  r_PTH_5p0_10p0  r_PTH_10p0_15p0  \
# r_PTH_0p0_5p0              2.615974       -0.744819         0.574816
# r_PTH_5p0_10p0            -0.744819        5.324318        -0.806734
# r_PTH_10p0_15p0            0.574816       -0.806734         6.017444
# r_PTH_15p0_20p0            0.246265        0.761936        -0.840373
# r_PTH_20p0_25p0            0.219220        0.332124         0.577763
# r_PTH_25p0_30p0            0.128047        0.251722         0.202158
# r_PTH_30p0_35p0            0.065874        0.092868         0.088820
# r_PTH_35p0_45p0            0.061578        0.097777         0.085300
# r_PTH_45p0_60p0           -0.015864       -0.022010        -0.025826
# r_PTH_60p0_80p0           -0.040551       -0.095948        -0.097314
# r_PTH_80p0_100p0          -0.036419       -0.094141        -0.104859
# r_PTH_100p0_120p0         -0.029166       -0.061527        -0.058975
# r_PTH_120p0_140p0         -0.020229       -0.033675        -0.032477
# r_PTH_140p0_170p0         -0.028644       -0.039927        -0.037323
# r_PTH_170p0_200p0         -0.019152       -0.026561        -0.025081
# r_PTH_200p0_250p0         -0.020475       -0.024899        -0.022567
# r_PTH_250p0_350p0         -0.019096       -0.026505        -0.023965
# r_PTH_350p0_450p0         -0.005408       -0.007023        -0.006180
# r_PTH_450p0_10000p0       -0.003758       -0.005162        -0.004920
# r_NJ_0p0_1p0               3.237854        6.014299         6.295079
# r_NJ_1p0_2p0              -0.039738       -0.090891        -0.050074
# r_NJ_2p0_3p0              -0.106051       -0.305355        -0.301715
# r_NJ_3p0_4p0              -0.042750       -0.117324        -0.119931
# r_NJ_4p0_100p0            -0.005215       -0.030504        -0.034470
# r_PTJ0_m10000p0_30p0       2.953345        5.469479         5.686106
# r_PTJ0_30p0_40p0           0.079345        0.166481         0.222366
# r_PTJ0_40p0_55p0          -0.025578       -0.064338        -0.030782
# r_PTJ0_55p0_75p0          -0.021341       -0.099700        -0.137229
# r_PTJ0_75p0_95p0          -0.007747       -0.085008        -0.047795
# r_PTJ0_95p0_120p0         -0.022968       -0.064983        -0.070805
# r_PTJ0_120p0_150p0        -0.017400       -0.044118        -0.057816
# r_PTJ0_150p0_200p0        -0.011440       -0.036848        -0.036591
# r_PTJ0_200p0_10000p0       1.658107        2.897143         2.735075
#
#                       r_PTH_15p0_20p0  r_PTH_20p0_25p0  r_PTH_25p0_30p0  \
# r_PTH_0p0_5p0                0.246265         0.219220         0.128047
# r_PTH_5p0_10p0               0.761936         0.332124         0.251722
# r_PTH_10p0_15p0             -0.840373         0.577763         0.202158
# r_PTH_15p0_20p0              5.028184        -0.871175         0.404764
# r_PTH_20p0_25p0             -0.871175         4.525218        -0.945783
# r_PTH_25p0_30p0              0.404764        -0.945783         3.932869
# r_PTH_30p0_35p0              0.064681         0.232486        -0.868502
# r_PTH_35p0_45p0              0.104561         0.067199         0.224427
# r_PTH_45p0_60p0              0.006743         0.039530         0.059105
# r_PTH_60p0_80p0             -0.044666        -0.012021         0.039656
# r_PTH_80p0_100p0            -0.056357        -0.032983         0.011617
# r_PTH_100p0_120p0           -0.034088        -0.014452         0.011078
# r_PTH_120p0_140p0           -0.020522        -0.005157         0.007506
# r_PTH_140p0_170p0           -0.027409        -0.005487         0.006392
# r_PTH_170p0_200p0           -0.018590        -0.004144         0.003527
# r_PTH_200p0_250p0           -0.018411        -0.002543         0.003479
# r_PTH_250p0_350p0           -0.018545        -0.004680         0.002564
# r_PTH_350p0_450p0           -0.004942        -0.000837         0.001079
# r_PTH_450p0_10000p0         -0.003788        -0.000995         0.000438
# r_NJ_0p0_1p0                 5.206872         4.152370         2.949331
# r_NJ_1p0_2p0                 0.233830         0.373033         0.575524
# r_NJ_2p0_3p0                -0.144137        -0.095590         0.074783
# r_NJ_3p0_4p0                -0.060611        -0.038603         0.015672
# r_NJ_4p0_100p0              -0.011927        -0.005689         0.007640
# r_PTJ0_m10000p0_30p0         4.644445         3.652638         2.521284
# r_PTJ0_30p0_40p0             0.390791         0.415674         0.503395
# r_PTJ0_40p0_55p0             0.022130         0.118509         0.204715
# r_PTJ0_55p0_75p0             0.009308        -0.005853         0.099316
# r_PTJ0_75p0_95p0            -0.016839         0.009613         0.033237
# r_PTJ0_95p0_120p0           -0.030704        -0.019386         0.041243
# r_PTJ0_120p0_150p0          -0.018583        -0.014736         0.012176
# r_PTJ0_150p0_200p0          -0.018478         0.006078         0.014139
# r_PTJ0_200p0_10000p0         2.556932         1.700756         1.275821
#
#                       r_PTH_30p0_35p0  r_PTH_35p0_45p0  r_PTH_45p0_60p0  \
# r_PTH_0p0_5p0                0.065874         0.061578        -0.015864
# r_PTH_5p0_10p0               0.092868         0.097777        -0.022010
# r_PTH_10p0_15p0              0.088820         0.085300        -0.025826
# r_PTH_15p0_20p0              0.064681         0.104561         0.006743
# r_PTH_20p0_25p0              0.232486         0.067199         0.039530
# r_PTH_25p0_30p0             -0.868502         0.224427         0.059105
# r_PTH_30p0_35p0              3.135810        -0.620468         0.129746
# r_PTH_35p0_45p0             -0.620468         3.886581        -0.149007
# r_PTH_45p0_60p0              0.129746        -0.149007         3.503391
# r_PTH_60p0_80p0              0.048225         0.225053         0.116219
# r_PTH_80p0_100p0             0.022964         0.120868         0.224755
# r_PTH_100p0_120p0            0.020791         0.087325         0.144088
# r_PTH_120p0_140p0            0.016343         0.057647         0.091545
# r_PTH_140p0_170p0            0.020364         0.066011         0.102269
# r_PTH_170p0_200p0            0.012975         0.041634         0.064414
# r_PTH_200p0_250p0            0.014213         0.041838         0.062938
# r_PTH_250p0_350p0            0.011759         0.037140         0.057233
# r_PTH_350p0_450p0            0.003852         0.011269         0.016947
# r_PTH_450p0_10000p0          0.002343         0.007251         0.011246
# r_NJ_0p0_1p0                 1.820563         2.148047         0.770820
# r_NJ_1p0_2p0                 0.698847         1.820206         2.637955
# r_NJ_2p0_3p0                 0.074884         0.420242         0.726207
# r_NJ_3p0_4p0                 0.028822         0.126385         0.235122
# r_NJ_4p0_100p0               0.011562         0.055108         0.098815
# r_PTJ0_m10000p0_30p0         1.472592         1.728091         0.671150
# r_PTJ0_30p0_40p0             0.530759         0.969188         0.920256
# r_PTJ0_40p0_55p0             0.218868         0.749261         1.097707
# r_PTJ0_55p0_75p0             0.116807         0.418429         0.827015
# r_PTJ0_75p0_95p0             0.073787         0.197612         0.359987
# r_PTJ0_95p0_120p0            0.010624         0.134432         0.223828
# r_PTJ0_120p0_150p0           0.035139         0.086390         0.150796
# r_PTJ0_150p0_200p0           0.009830         0.063304         0.117084
# r_PTJ0_200p0_10000p0         0.616561         1.023961         0.724647
#
#                       r_PTH_60p0_80p0  ...  r_NJ_4p0_100p0  \
# r_PTH_0p0_5p0               -0.040551  ...       -0.005215
# r_PTH_5p0_10p0              -0.095948  ...       -0.030504
# r_PTH_10p0_15p0             -0.097314  ...       -0.034470
# r_PTH_15p0_20p0             -0.044666  ...       -0.011927
# r_PTH_20p0_25p0             -0.012021  ...       -0.005689
# r_PTH_25p0_30p0              0.039656  ...        0.007640
# r_PTH_30p0_35p0              0.048225  ...        0.011562
# r_PTH_35p0_45p0              0.225053  ...        0.055108
# r_PTH_45p0_60p0              0.116219  ...        0.098815
# r_PTH_60p0_80p0              2.442745  ...        0.091358
# r_PTH_80p0_100p0             0.080987  ...        0.062119
# r_PTH_100p0_120p0            0.137084  ...        0.045994
# r_PTH_120p0_140p0            0.085124  ...        0.035552
# r_PTH_140p0_170p0            0.098266  ...        0.038913
# r_PTH_170p0_200p0            0.062194  ...        0.024644
# r_PTH_200p0_250p0            0.061830  ...        0.025745
# r_PTH_250p0_350p0            0.055701  ...        0.021293
# r_PTH_350p0_450p0            0.016602  ...        0.006589
# r_PTH_450p0_10000p0          0.011054  ...        0.004234
# r_NJ_0p0_1p0                -0.140748  ...       -0.024764
# r_NJ_1p0_2p0                 2.304164  ...        0.148637
# r_NJ_2p0_3p0                 0.755152  ...        0.327688
# r_NJ_3p0_4p0                 0.237700  ...       -0.393770
# r_NJ_4p0_100p0               0.091358  ...        0.491285
# r_PTJ0_m10000p0_30p0         0.060057  ...       -0.013149
# r_PTJ0_30p0_40p0             0.547014  ...        0.035101
# r_PTJ0_40p0_55p0             0.756046  ...        0.093216
# r_PTJ0_55p0_75p0             0.874978  ...        0.058921
# r_PTJ0_75p0_95p0             0.522077  ...        0.068095
# r_PTJ0_95p0_120p0            0.264158  ...        0.058522
# r_PTJ0_120p0_150p0           0.151535  ...        0.051081
# r_PTJ0_150p0_200p0           0.111498  ...        0.053927
# r_PTJ0_200p0_10000p0         0.358723  ...        1.142657
#
#                       r_PTJ0_m10000p0_30p0  r_PTJ0_30p0_40p0  \
# r_PTH_0p0_5p0                     2.953345          0.079345
# r_PTH_5p0_10p0                    5.469479          0.166481
# r_PTH_10p0_15p0                   5.686106          0.222366
# r_PTH_15p0_20p0                   4.644445          0.390791
# r_PTH_20p0_25p0                   3.652638          0.415674
# r_PTH_25p0_30p0                   2.521284          0.503395
# r_PTH_30p0_35p0                   1.472592          0.530759
# r_PTH_35p0_45p0                   1.728091          0.969188
# r_PTH_45p0_60p0                   0.671150          0.920256
# r_PTH_60p0_80p0                   0.060057          0.547014
# r_PTH_80p0_100p0                 -0.150187          0.218232
# r_PTH_100p0_120p0                -0.137038          0.165844
# r_PTH_120p0_140p0                -0.099634          0.108432
# r_PTH_140p0_170p0                -0.144765          0.117431
# r_PTH_170p0_200p0                -0.103367          0.081574
# r_PTH_200p0_250p0                -0.106349          0.083936
# r_PTH_250p0_350p0                -0.103974          0.065876
# r_PTH_350p0_450p0                -0.031818          0.021522
# r_PTH_450p0_10000p0              -0.019289          0.012457
# r_NJ_0p0_1p0                     40.238038         -4.879764
# r_NJ_1p0_2p0                     -8.317550         10.624219
# r_NJ_2p0_3p0                     -0.266151         -0.854583
# r_NJ_3p0_4p0                     -0.294732          0.095824
# r_NJ_4p0_100p0                   -0.013149          0.035101
# r_PTJ0_m10000p0_30p0             47.002568        -22.360512
# r_PTJ0_30p0_40p0                -22.360512         40.756807
# r_PTJ0_40p0_55p0                 12.054593        -27.642659
# r_PTJ0_55p0_75p0                 -4.439480         10.472277
# r_PTJ0_75p0_95p0                  1.379649         -3.555720
# r_PTJ0_95p0_120p0                -0.661548          1.361417
# r_PTJ0_120p0_150p0                0.004246         -0.178737
# r_PTJ0_150p0_200p0               -0.131310          0.176914
# r_PTJ0_200p0_10000p0             12.960678          2.066487
#
#                       r_PTJ0_40p0_55p0  r_PTJ0_55p0_75p0  r_PTJ0_75p0_95p0  \
# r_PTH_0p0_5p0                -0.025578         -0.021341         -0.007747
# r_PTH_5p0_10p0               -0.064338         -0.099700         -0.085008
# r_PTH_10p0_15p0              -0.030782         -0.137229         -0.047795
# r_PTH_15p0_20p0               0.022130          0.009308         -0.016839
# r_PTH_20p0_25p0               0.118509         -0.005853          0.009613
# r_PTH_25p0_30p0               0.204715          0.099316          0.033237
# r_PTH_30p0_35p0               0.218868          0.116807          0.073787
# r_PTH_35p0_45p0               0.749261          0.418429          0.197612
# r_PTH_45p0_60p0               1.097707          0.827015          0.359987
# r_PTH_60p0_80p0               0.756046          0.874978          0.522077
# r_PTH_80p0_100p0              0.400698          0.342018          0.409713
# r_PTH_100p0_120p0             0.182168          0.197324          0.187854
# r_PTH_120p0_140p0             0.125515          0.096575          0.105863
# r_PTH_140p0_170p0             0.133305          0.108527          0.088682
# r_PTH_170p0_200p0             0.075443          0.066790          0.046316
# r_PTH_200p0_250p0             0.079946          0.064635          0.046617
# r_PTH_250p0_350p0             0.072045          0.057453          0.039271
# r_PTH_350p0_450p0             0.020695          0.017174          0.012384
# r_PTH_450p0_10000p0           0.014951          0.010568          0.007793
# r_NJ_0p0_1p0                 -0.200054         -0.985368         -0.342975
# r_NJ_1p0_2p0                  2.667236          2.695997          1.357371
# r_NJ_2p0_3p0                  1.438859          1.036624          0.699882
# r_NJ_3p0_4p0                  0.186634          0.215530          0.228254
# r_NJ_4p0_100p0                0.093216          0.058921          0.068095
# r_PTJ0_m10000p0_30p0         12.054593         -4.439480          1.379649
# r_PTJ0_30p0_40p0            -27.642659         10.472277         -3.555720
# r_PTJ0_40p0_55p0             35.199971        -16.755397          6.946119
# r_PTJ0_55p0_75p0            -16.755397         19.700325        -10.221878
# r_PTJ0_75p0_95p0              6.946119        -10.221878         12.429703
# r_PTJ0_95p0_120p0            -2.186430          4.176725         -6.147810
# r_PTJ0_120p0_150p0            0.732246         -1.055903          2.016089
# r_PTJ0_150p0_200p0           -0.023589          0.294682         -0.345455
# r_PTJ0_200p0_10000p0          0.637364         -1.007166          1.301013
#
#                       r_PTJ0_95p0_120p0  r_PTJ0_120p0_150p0  \
# r_PTH_0p0_5p0                 -0.022968           -0.017400
# r_PTH_5p0_10p0                -0.064983           -0.044118
# r_PTH_10p0_15p0               -0.070805           -0.057816
# r_PTH_15p0_20p0               -0.030704           -0.018583
# r_PTH_20p0_25p0               -0.019386           -0.014736
# r_PTH_25p0_30p0                0.041243            0.012176
# r_PTH_30p0_35p0                0.010624            0.035139
# r_PTH_35p0_45p0                0.134432            0.086390
# r_PTH_45p0_60p0                0.223828            0.150796
# r_PTH_60p0_80p0                0.264158            0.151535
# r_PTH_80p0_100p0               0.248854            0.119828
# r_PTH_100p0_120p0              0.194430            0.123842
# r_PTH_120p0_140p0              0.086458            0.106225
# r_PTH_140p0_170p0              0.073048            0.083327
# r_PTH_170p0_200p0              0.042127            0.030418
# r_PTH_200p0_250p0              0.035659            0.027510
# r_PTH_250p0_350p0              0.027285            0.023069
# r_PTH_350p0_450p0              0.008014            0.006631
# r_PTH_450p0_10000p0            0.005872            0.004548
# r_NJ_0p0_1p0                  -0.311645           -0.210304
# r_NJ_1p0_2p0                   0.754866            0.474932
# r_NJ_2p0_3p0                   0.572931            0.350278
# r_NJ_3p0_4p0                   0.151466            0.154392
# r_NJ_4p0_100p0                 0.058522            0.051081
# r_PTJ0_m10000p0_30p0          -0.661548            0.004246
# r_PTJ0_30p0_40p0               1.361417           -0.178737
# r_PTJ0_40p0_55p0              -2.186430            0.732246
# r_PTJ0_55p0_75p0               4.176725           -1.055903
# r_PTJ0_75p0_95p0              -6.147810            2.016089
# r_PTJ0_95p0_120p0              6.881327           -2.742153
# r_PTJ0_120p0_150p0            -2.742153            2.904035
# r_PTJ0_150p0_200p0             0.663182           -0.830932
# r_PTJ0_200p0_10000p0          -2.019382            1.918818
#
#                       r_PTJ0_150p0_200p0  r_PTJ0_200p0_10000p0
# r_PTH_0p0_5p0                  -0.011440              1.658107
# r_PTH_5p0_10p0                 -0.036848              2.897143
# r_PTH_10p0_15p0                -0.036591              2.735075
# r_PTH_15p0_20p0                -0.018478              2.556932
# r_PTH_20p0_25p0                 0.006078              1.700756
# r_PTH_25p0_30p0                 0.014139              1.275821
# r_PTH_30p0_35p0                 0.009830              0.616561
# r_PTH_35p0_45p0                 0.063304              1.023961
# r_PTH_45p0_60p0                 0.117084              0.724647
# r_PTH_60p0_80p0                 0.111498              0.358723
# r_PTH_80p0_100p0                0.079540              0.084694
# r_PTH_100p0_120p0               0.062828              0.118316
# r_PTH_120p0_140p0               0.054624              0.205500
# r_PTH_140p0_170p0               0.082907              0.290988
# r_PTH_170p0_200p0               0.055769              0.358847
# r_PTH_200p0_250p0               0.033960              0.697043
# r_PTH_250p0_350p0               0.015580              0.658405
# r_PTH_350p0_450p0               0.003243              0.222620
# r_PTH_450p0_10000p0             0.002248              0.087033
# r_NJ_0p0_1p0                   -0.126635             13.397071
# r_NJ_1p0_2p0                    0.287480              0.860709
# r_NJ_2p0_3p0                    0.304784              1.509486
# r_NJ_3p0_4p0                    0.109935              1.506534
# r_NJ_4p0_100p0                  0.053927              1.142657
# r_PTJ0_m10000p0_30p0           -0.131310             12.960678
# r_PTJ0_30p0_40p0                0.176914              2.066487
# r_PTJ0_40p0_55p0               -0.023589              0.637364
# r_PTJ0_55p0_75p0                0.294682             -1.007166
# r_PTJ0_75p0_95p0               -0.345455              1.301013
# r_PTJ0_95p0_120p0               0.663182             -2.019382
# r_PTJ0_120p0_150p0             -0.830932              1.918818
# r_PTJ0_150p0_200p0              0.978928             -3.813217
# r_PTJ0_200p0_10000p0           -3.813217            188.882713
#
# [33 rows x 33 columns]

# %%
dataframe_to_yaml_rows(
    df=Cov_Theor, 
    output_yaml="cov_theory.yaml",
    label_map=label_map,
    target_order=target_order,
    zero_tol=1e-12, ## zero_tol is the threshold below which numbers are forced to 0.0 when exporting
)

# %%
def extract_diag_sqrt(Cov_Theor):
    """
    Extract the diagonal elements of a pandas DataFrame
    and return their square roots in a dictionary.

    Parameters
    ----------
    Cov_Theor : pandas.DataFrame
        Square covariance matrix.

    Returns
    -------
    dict
        Dictionary with column/index names as keys and
        sqrt(diagonal element) as values.
    """
    diag_values = np.diag(Cov_Theor.values)
    
    return {
        name: np.sqrt(value)
        for name, value in zip(Cov_Theor.index, diag_values)
    }

# %%
extract_diag_sqrt(Cov_Theor)
# Out:
# {'r_PTH_0p0_5p0': 0.42438122881815304,
#  'r_PTH_5p0_10p0': 0.8076970717507115,
#  'r_PTH_10p0_15p0': 0.7946793751829242,
#  'r_PTH_15p0_20p0': 0.6572023636197347,
#  'r_PTH_20p0_25p0': 0.4892021096810138,
#  'r_PTH_25p0_30p0': 0.33594488606221046,
#  'r_PTH_30p0_35p0': 0.20307989118587963,
#  'r_PTH_35p0_45p0': 0.44900491824387634,
#  'r_PTH_45p0_60p0': 0.6168400139783011,
#  'r_PTH_60p0_80p0': 0.5631798969419988,
#  'r_PTH_80p0_100p0': 0.3811706728180769,
#  'r_PTH_100p0_120p0': 0.24376637409975047,
#  'r_PTH_120p0_140p0': 0.15533203894447667,
#  'r_PTH_140p0_170p0': 0.17485510724175593,
#  'r_PTH_170p0_200p0': 0.11225189430789168,
#  'r_PTH_200p0_250p0': 0.10989812910205278,
#  'r_PTH_250p0_350p0': 0.1014527913301051,
#  'r_PTH_350p0_450p0': 0.03024735480824003,
#  'r_PTH_450p0_10000p0': 0.021259812444434034,
#  'r_NJ_0p0_1p0': 3.880860726008241,
#  'r_NJ_1p0_2p0': 1.5607224370099548,
#  'r_NJ_2p0_3p0': 1.004850073972498,
#  'r_NJ_3p0_4p0': 0.29735331303645357,
#  'r_NJ_4p0_100p0': 0.14261595161697135,
#  'r_PTJ0_m10000p0_30p0': 3.880860726008241,
#  'r_PTJ0_30p0_40p0': 0.5814693873837886,
#  'r_PTJ0_40p0_55p0': 0.679067576341647,
#  'r_PTJ0_55p0_75p0': 0.5576947625324283,
#  'r_PTJ0_75p0_95p0': 0.34542456387047416,
#  'r_PTJ0_95p0_120p0': 0.27552640195101524,
#  'r_PTJ0_120p0_150p0': 0.18702733019078407,
#  'r_PTJ0_150p0_200p0': 0.1540234389024232,
#  'r_PTJ0_200p0_10000p0': 3.830844457419081}

# %%
# For PCA

dataframe_to_yaml_rows(
    df=cov_tot, 
    output_yaml="cov_tot_PTH.yaml",
    label_map=label_map,
    target_order=target_order,
    zero_tol=1e-12, ## zero_tol is the threshold below which numbers are forced to 0.0 when exporting
)
